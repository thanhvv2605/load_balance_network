# %%
# %cd ../..
# Out:
# d:\HUST\WRSN\Load_balancing_problem\load_balance_network
# C:\Users\Nam\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls

# %%
import sys
import os
# sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from physical_env.network.NetworkIO import NetworkIO


netIO = NetworkIO("physical_env/network/network_scenarios/100_normal_9.yaml")
env, net = netIO.makeNetwork()

for node in net.listNodes:
    node.net = net
    node.env = env
# Out:
# Num cluster: 17
# 100
# target 100
# target [<Target.Target object at 0x00000234A631E7D0>, <Target.Target object at 0x00000234A6834590>, <Target.Target object at 0x00000234A65BA850>, <Target.Target object at 0x00000234A6927590>, <Target.Target object at 0x00000234A69278D0>, <Target.Target object at 0x00000234A6927110>, <Target.Target object at 0x00000234A6927B10>, <Target.Target object at 0x00000234A6927B50>, <Target.Target object at 0x00000234A6927C90>, <Target.Target object at 0x00000234A6927890>, <Target.Target object at 0x00000234A6927B90>, <Target.Target object at 0x00000234A6927D90>, <Target.Target object at 0x00000234A6927990>, <Target.Target object at 0x00000234A6927C10>, <Target.Target object at 0x00000234A6927E50>, <Target.Target object at 0x00000234A6927F90>, <Target.Target object at 0x00000234A6927E90>, <Target.Target object at 0x00000234A6927A90>, <Target.Target object at 0x00000234A6927F10>, <Target.Target object at 0x00000234A6927DD0>, <Target.Target object at 0x00000234A6927C50>, <Target.Target object at 0x00000234A6927F50>, <Target.Target object at 0x00000234A6927CD0>, <Target.Target object at 0x00000234A6927E10>, <Target.Target object at 0x00000234A6927FD0>, <Target.Target object at 0x00000234A6927ED0>, <Target.Target object at 0x00000234A6927D10>, <Target.Target object at 0x00000234A6927A50>, <Target.Target object at 0x00000234A6927AD0>, <Target.Target object at 0x00000234A6919490>, <Target.Target object at 0x00000234A687B9D0>, <Target.Target object at 0x00000234A68FCBD0>, <Target.Target object at 0x00000234A68FE250>, <Target.Target object at 0x00000234A68FCC10>, <Target.Target object at 0x00000234A68FCF50>, <Target.Target object at 0x00000234A6959BD0>, <Target.Target object at 0x00000234A6958050>, <Target.Target object at 0x00000234A69582D0>, <Target.Target object at 0x00000234A6958290>, <Target.Target object at 0x00000234A6958250>, <Target.Target object at 0x00000234A6958110>, <Target.Target object at 0x00000234A6958150>, <Target.Target object at 0x00000234A6958350>, <Target.Target object at 0x00000234A6958210>, <Target.Target object at 0x00000234A6958090>, <Target.Target object at 0x00000234A69585D0>, <Target.Target object at 0x00000234A69581D0>, <Target.Target object at 0x00000234A6958410>, <Target.Target object at 0x00000234A6958450>, <Target.Target object at 0x00000234A6958590>, <Target.Target object at 0x00000234A6958550>, <Target.Target object at 0x00000234A69580D0>, <Target.Target object at 0x00000234A6958310>, <Target.Target object at 0x00000234A6958650>, <Target.Target object at 0x00000234A6958510>, <Target.Target object at 0x00000234A6958190>, <Target.Target object at 0x00000234A69588D0>, <Target.Target object at 0x00000234A69584D0>, <Target.Target object at 0x00000234A6958710>, <Target.Target object at 0x00000234A6958750>, <Target.Target object at 0x00000234A6958890>, <Target.Target object at 0x00000234A6958850>, <Target.Target object at 0x00000234A6958390>, <Target.Target object at 0x00000234A6958610>, <Target.Target object at 0x00000234A6958950>, <Target.Target object at 0x00000234A6958810>, <Target.Target object at 0x00000234A6958490>, <Target.Target object at 0x00000234A6958BD0>, <Target.Target object at 0x00000234A69587D0>, <Target.Target object at 0x00000234A6958A10>, <Target.Target object at 0x00000234A6958A50>, <Target.Target object at 0x00000234A6958B90>, <Target.Target object at 0x00000234A6958B50>, <Target.Target object at 0x00000234A6958690>, <Target.Target object at 0x00000234A6958910>, <Target.Target object at 0x00000234A6958C50>, <Target.Target object at 0x00000234A6958B10>, <Target.Target object at 0x00000234A6958790>, <Target.Target object at 0x00000234A6958ED0>, <Target.Target object at 0x00000234A6958AD0>, <Target.Target object at 0x00000234A69583D0>, <Target.Target object at 0x00000234A6958D10>, <Target.Target object at 0x00000234A6958D50>, <Target.Target object at 0x00000234A6958E90>, <Target.Target object at 0x00000234A6958E50>, <Target.Target object at 0x00000234A6958990>, <Target.Target object at 0x00000234A ...
# target
# [[9, 1], [14, 3], [5, 7], [6, 7], [15, 3], [2, 7], [3, 6], [0, 8], [11, 6], [12, 4], [7, 8], [16, 7], [8, 7], [4, 5], [1, 8], [10, 6], [13, 7]]
# Common point:  [[9, [11, 1, 0, 10, 13]], [14, [2, 7, 8]], [5, [12, 8, 1]], [6, [4, 10, 13]], [15, [1]], [2, [8]], [3, [8]], [0, [10, 4, 13]], [11, [1, 10, 13]], [12, [1]], [7, []], [16, [4, 10, 13]], [8, []], [4, [10, 13]], [1, [13]], [10, [13]], [13, []]]
# Số target tải mỗi cluster
# [[9, 1], [14, 3], [5, 7], [6, 7], [15, 3], [2, 10], [3, 6], [0, 8], [11, 7], [12, 11], [7, 8], [16, 7], [8, 11.5], [4, 19], [1, 14.5], [10, 16.5], [13, 13.625]]

# %%
import matplotlib.pyplot as plt
import numpy as np
# from moviepy.editor import ImageSequenceClip
from IPython.display import Video, display

plt.figure() 
image_files = []

# colors = ['red', 'blue', 'yellow', 'green', 'purple', 'pink', 'brown', 'cyan', 'magenta', 'lime', 'teal', 'lavender', 'maroon', 'olive', 'navy', 'beige', 'indigo', 'turquoise']
shapes = ['<', '>', 's', 'p', 'x', '*', '^', 'v', 'h', 's', 'p', 'o']
colors = ['aliceblue', 'antiquewhite', 'aqua', 'aquamarine', 'azure', 'beige', 'bisque', 'green', 'blanchedalmond', 'blue', 'blueviolet', 'brown', 'burlywood', 'cadetblue', 'chartreuse', 'chocolate', 'coral', 'cornflowerblue', 'cornsilk', 'crimson', 'cyan', 'darkblue', 'darkcyan', 'darkgoldenrod', 'darkgray', 'darkgreen', 'darkgrey', 'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange', 'darkorchid', 'darkred', 'darksalmon', 'darkseagreen', 'darkslateblue', 'darkslategray', 'darkslategrey', 'darkturquoise', 'darkviolet', 'deeppink', 'deepskyblue', 'dimgray', 'dimgrey', 'dodgerblue', 'firebrick', 'floralwhite', 'forestgreen', 'fuchsia', 'gainsboro', 'ghostwhite', 'gold', 'goldenrod', 'gray', 'green', 'greenyellow', 'grey', 'honeydew', 'hotpink', 'indianred', 'indigo', 'ivory', 'khaki', 'lavender', 'lavenderblush', 'lawngreen', 'lemonchiffon', 'lightblue', 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue', 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'lime', 'limegreen', 'linen', 'magenta', 'maroon', 'mediumaquamarine', 'mediumblue', 'mediumorchid', 'mediumpurple', 'mediumseagreen', 'mediumslateblue', 'mediumspringgreen', 'mediumturquoise', 'mediumvioletred', 'midnightblue', 'mintcream', 'mistyrose', 'moccasin']

# def draw(path_to_save_image):
def draw():
    plt.figure(figsize=(9, 9))
    plt.scatter(net.baseStation.location[0], net.baseStation.location[1], marker= "*", color = "purple",s = 200)
    for i in range(len(net.targets_active)):
      if net.targets_active[i] == 0:
        plt.scatter(net.listTargets[i].location[0], net.listTargets[i].location[1], color="red", marker="*",s = 200)
      else:
        plt.scatter(net.listTargets[i].location[0], net.listTargets[i].location[1], color="blue", marker="*") 
    # print(net.targets_active)

         
    
    for cluster in net.listClusters:
    #  plt.scatter(cluster.centroid[0],cluster.centroid[1],color = "black")
     for node in cluster.listNodes:
        x = node.location[0]
        y = node.location[1]
        size = 20
        color = colors[cluster.id]
        type_node = node.__class__.__name__
        if(type_node == "InNode"): marker_ = shapes[0]
        if(type_node == "OutNode"):  marker_ = shapes[1]
        if(type_node == "SensorNode"): marker_ = shapes[2]
        if(type_node == "ConnectorNode"):  marker_ = shapes[3]
        if(node.status == 0): 
          size = 30
          color = "black"

        plt.scatter(x, y, color = color , marker = marker_,s=size)
        # label = str(round(node.energy/node.capacity*100,2))  +"|"+  str(node.id)
        label = str(round(node.energy/node.capacity*100,2))
        # plt.text(x, y, label, ha='center', va='center', fontsize=6, color='black')
          
    relayNodes = [node for node in net.listNodes if node.__class__.__name__ == "RelayNode"]
    for node in relayNodes:
      color = 'orange' 
      size = 20
      x = node.location[0]
      y = node.location[1]
      if(node.status == 0): 
          size = 30
          color = "black"
      plt.scatter(x, y, color = color , marker = 'o',s=size)
      
    #   label =  str(round(node.energy/node.capacity*100,2)) +"|" +  str(node.id)
    
      label =  str(round(node.energy/node.capacity*100,2)) 
      # plt.text(x, y,label, ha='center',va = "center", fontsize=6, color='black')
    plt.show()
    # plt.savefig()


path_prefix = "result/images"     

def log(net, mcs):
    
    while True:

        if net.env.now%10 == 0:
           path = path_prefix +"/" +str(net.env.now) + ".png"
          #  draw(path) 
        print(net.env.now,net.check_nodes(),net.check_targets())
       
        yield net.env.timeout(20.0) 

# netIO = NetworkIO("physical_env/network/network_scenarios/hanoi1000n150.yaml")
# env, net = netIO.makeNetwork()

# for node in net.listNodes:
#     node.net = net
#     node.env = env
print("list clusters",len(net.listClusters))
print("list nodes",len(net.listNodes))

draw()

     
x = env.process(net.operate())
env.process(log(net, None))
env.run(until=x)

   
draw()
# Out:
# list clusters 17
# list nodes 208
# 0 0 0
# 20.0 0 1
# 40.0 0 1
# 60.0 0 1
# 80.0 0 1
# 100.0 0 1
# 120.0 0 1
# 140.0 0 1
# 160.0 0 1
# 180.0 0 1
# 200.0 0 1
# 220.0 0 1
# 240.0 0 1
# 260.0 0 1
# 280.0 0 1
# 300.0 0 1
# 320.0 0 1
# 340.0 0 1
# 360.0 0 1
# 380.0 0 1
# 400.0 0 1
# 420.0 0 1
# 440.0 0 1
# 460.0 0 1
# 480.0 0 1
# 500.0 0 1
# 520.0 0 1
# 540.0 0 1
# 560.0 0 1
# 580.0 0 1
# 600.0 0 1
# 620.0 0 1
# 640.0 0 1
# 660.0 0 1
# 680.0 0 1
# 700.0 0 1
# 720.0 0 1
# 740.0 0 1
# 760.0 0 1
# 780.0 0 1
# 800.0 0 1
# 820.0 0 1
# 840.0 0 1
# 860.0 0 1
# 880.0 0 1
# 900.0 0 1
# 920.0 0 1
# 940.0 0 1
# 960.0 0 1
# 980.0 0 1
# 1000.0 0 1
# 1020.0 0 1
# 1040.0 0 1
# 1060.0 0 1
# 1080.0 0 1
# 1100.0 0 1
# 1120.0 0 1
# 1140.0 0 1
# 1160.0 0 1
# 1180.0 0 1
# 1200.0 0 1
# 1220.0 0 1
# 1240.0 0 1

# %%
net.targets_active
for node in net.listNodes:
    if node.status == 0:
        print(node.__class__.__name__)

for a in net.targets_active:
    if a == 0:
        print(a)
# Out:
# OutNode
# RelayNode
# RelayNode
# RelayNode
# 0
# 0
# 0
# 0
# 0

# %%
for node1 in net.listNodes:
    for node2 in net.listNodes:
        if node1.id == node2.id and node1.__class__.__name__ != node2.__class__.__name__:
            print(node1,node2)
            print(node1.id, node2.id)
            print()
# Out:
# <Nodes.SensorNode.SensorNode object at 0x000001E199CA5A90> <Nodes.RelayNode.RelayNode object at 0x000001E199CBC650>
# 72 72
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA5890> <Nodes.RelayNode.RelayNode object at 0x000001E199CBC490>
# 71 71
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA56D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CBC2D0>
# 70 70
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA5510> <Nodes.RelayNode.RelayNode object at 0x000001E199CBC110>
# 69 69
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C93FD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CBBF50>
# 68 68
#
# <Nodes.OutNode.OutNode object at 0x000001E199CA5150> <Nodes.RelayNode.RelayNode object at 0x000001E199CBBD50>
# 67 67
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199CA4F90> <Nodes.RelayNode.RelayNode object at 0x000001E199CBBB90>
# 66 66
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA4710> <Nodes.RelayNode.RelayNode object at 0x000001E199CBB9D0>
# 65 65
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199CA4CD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CBB850>
# 64 64
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA4B10> <Nodes.RelayNode.RelayNode object at 0x000001E199CBB690>
# 63 63
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199CA4950> <Nodes.RelayNode.RelayNode object at 0x000001E199CBB490>
# 62 62
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA4790> <Nodes.RelayNode.RelayNode object at 0x000001E199CBB2D0>
# 61 61
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199CA4590> <Nodes.RelayNode.RelayNode object at 0x000001E199CBB110>
# 60 60
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA43D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CBAF50>
# 59 59
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C802D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CBADD0>
# 58 58
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C93350> <Nodes.RelayNode.RelayNode object at 0x000001E199CBAC10>
# 57 57
#
# <Nodes.OutNode.OutNode object at 0x000001E199C93DD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CBAA50>
# 56 56
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C93C10> <Nodes.RelayNode.RelayNode object at 0x000001E199CBA850>
# 55 55
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C93A50> <Nodes.RelayNode.RelayNode object at 0x000001E199CBA690>
# 54 54
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C93850> <Nodes.RelayNode.RelayNode object at 0x000001E199CBA4D0>
# 53 53
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C93690> <Nodes.RelayNode.RelayNode object at 0x000001E199CBA310>
# 52 52
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C934D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CBA190>
# 51 51
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C93250> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9FD0>
# 50 50
#
# <Nodes.OutNode.OutNode object at 0x000001E199C93090> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9E10>
# 49 49
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C92ED0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9C10>
# 48 48
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C92D10> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9A50>
# 47 47
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C92B50> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9890>
# 46 46
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C54410> <Nodes.RelayNode.RelayNode object at 0x000001E199CB96D0>
# 45 45
#
# <Nodes.OutNode.OutNode object at 0x000001E199C4ADD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9510>
# 44 44
#
# <Nodes.OutNode.OutNode object at 0x000001E1997BCF90> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9350>
# 43 43
#
# <Nodes.InNode.InNode object at 0x000001E1997BA850> <Nodes.RelayNode.RelayNode object at 0x000001E199CB9190>
# 42 42
#
# <Nodes.InNode.InNode object at 0x000001E1997FDC10> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8FD0>
# 41 41
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C7E610> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8E10>
# 40 40
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C7E750> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8C50>
# 39 39
#
# <Nodes.SensorNode.SensorNode object at 0x000001E19984A890> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8A90>
# 38 38
#
# <Nodes.OutNode.OutNode object at 0x000001E199C7DB50> <Nodes.RelayNode.RelayNode object at 0x000001E199CB88D0>
# 37 37
#
# <Nodes.OutNode.OutNode object at 0x000001E199C72010> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8750>
# 36 36
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C73350> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8590>
# 35 35
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C718D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB83D0>
# 34 34
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199780250> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8210>
# 33 33
#
# <Nodes.SensorNode.SensorNode object at 0x000001E197723CD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB8050>
# 32 32
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E196E62310> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3E50>
# 31 31
#
# <Nodes.SensorNode.SensorNode object at 0x000001E1976BAED0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3B10>
# 30 30
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1973BE450> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3A90>
# 29 29
#
# <Nodes.SensorNode.SensorNode object at 0x000001E1977354D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3910>
# 28 28
#
# <Nodes.OutNode.OutNode object at 0x000001E19984AF50> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3750>
# 27 27
#
# <Nodes.InNode.InNode object at 0x000001E1977261D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3550>
# 26 26
#
# <Nodes.SensorNode.SensorNode object at 0x000001E1997D5850> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3390>
# 25 25
#
# <Nodes.SensorNode.SensorNode object at 0x000001E197743010> <Nodes.RelayNode.RelayNode object at 0x000001E199CB31D0>
# 24 24
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C5F750> <Nodes.RelayNode.RelayNode object at 0x000001E199CB3010>
# 23 23
#
# <Nodes.SensorNode.SensorNode object at 0x000001E1997F1D10> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2E50>
# 22 22
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199C80850> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2C90>
# 21 21
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E19772C590> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2AD0>
# 20 20
#
# <Nodes.SensorNode.SensorNode object at 0x000001E19765DA10> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2950>
# 19 19
#
# <Nodes.OutNode.OutNode object at 0x000001E197734B90> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2790>
# 18 18
#
# <Nodes.OutNode.OutNode object at 0x000001E197734F90> <Nodes.RelayNode.RelayNode object at 0x000001E199CB25D0>
# 17 17
#
# <Nodes.InNode.InNode object at 0x000001E1977347D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2410>
# 16 16
#
# <Nodes.InNode.InNode object at 0x000001E197734210> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2250>
# 15 15
#
# <Nodes.InNode.InNode object at 0x000001E197734AD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB2090>
# 14 14
#
# <Nodes.SensorNode.SensorNode object at 0x000001E19766D9D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB1ED0>
# 13 13
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1976C6ED0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB1D10>
# 12 12
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199807D90> <Nodes.RelayNode.RelayNode object at 0x000001E199CB1B50>
# 11 11
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1D7B7A190> <Nodes.RelayNode.RelayNode object at 0x000001E199CB1990>
# 10 10
#
# <Nodes.SensorNode.SensorNode object at 0x000001E1970FE290> <Nodes.RelayNode.RelayNode object at 0x000001E199CB1810>
# 9 9
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199805CD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB1650>
# 8 8
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199806F90> <Nodes.RelayNode.RelayNode object at 0x000001E199CB1490>
# 7 7
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199804D50> <Nodes.RelayNode.RelayNode object at 0x000001E199CB12D0>
# 6 6
#
# <Nodes.SensorNode.SensorNode object at 0x000001E199807BD0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB10D0>
# 5 5
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E19764F4D0> <Nodes.RelayNode.RelayNode object at 0x000001E199CB0F10>
# 4 4
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1975F2850> <Nodes.RelayNode.RelayNode object at 0x000001E197726290>
# 3 3
#
# <Nodes.SensorNode.SensorNode object at 0x000001E1997E5410> <Nodes.RelayNode.RelayNode object at 0x000001E19983F310>
# 2 2
#
# <Nodes.OutNode.OutNode object at 0x000001E19985EF50> <Nodes.RelayNode.RelayNode object at 0x000001E199C806D0>
# 1 1
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBC650> <Nodes.SensorNode.SensorNode object at 0x000001E199CA5A90>
# 72 72
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBC490> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA5890>
# 71 71
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBC2D0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA56D0>
# 70 70
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBC110> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA5510>
# 69 69
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBBF50> <Nodes.SensorNode.SensorNode object at 0x000001E199C93FD0>
# 68 68
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBBD50> <Nodes.OutNode.OutNode object at 0x000001E199CA5150>
# 67 67
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBBB90> <Nodes.SensorNode.SensorNode object at 0x000001E199CA4F90>
# 66 66
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBB9D0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA4710>
# 65 65
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBB850> <Nodes.SensorNode.SensorNode object at 0x000001E199CA4CD0>
# 64 64
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBB690> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA4B10>
# 63 63
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBB490> <Nodes.SensorNode.SensorNode object at 0x000001E199CA4950>
# 62 62
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBB2D0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA4790>
# 61 61
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBB110> <Nodes.SensorNode.SensorNode object at 0x000001E199CA4590>
# 60 60
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBAF50> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199CA43D0>
# 59 59
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBADD0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C802D0>
# 58 58
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBAC10> <Nodes.SensorNode.SensorNode object at 0x000001E199C93350>
# 57 57
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBAA50> <Nodes.OutNode.OutNode object at 0x000001E199C93DD0>
# 56 56
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBA850> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C93C10>
# 55 55
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBA690> <Nodes.SensorNode.SensorNode object at 0x000001E199C93A50>
# 54 54
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBA4D0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C93850>
# 53 53
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBA310> <Nodes.SensorNode.SensorNode object at 0x000001E199C93690>
# 52 52
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CBA190> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C934D0>
# 51 51
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9FD0> <Nodes.SensorNode.SensorNode object at 0x000001E199C93250>
# 50 50
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9E10> <Nodes.OutNode.OutNode object at 0x000001E199C93090>
# 49 49
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9C10> <Nodes.SensorNode.SensorNode object at 0x000001E199C92ED0>
# 48 48
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9A50> <Nodes.SensorNode.SensorNode object at 0x000001E199C92D10>
# 47 47
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9890> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C92B50>
# 46 46
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB96D0> <Nodes.SensorNode.SensorNode object at 0x000001E199C54410>
# 45 45
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9510> <Nodes.OutNode.OutNode object at 0x000001E199C4ADD0>
# 44 44
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9350> <Nodes.OutNode.OutNode object at 0x000001E1997BCF90>
# 43 43
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB9190> <Nodes.InNode.InNode object at 0x000001E1997BA850>
# 42 42
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8FD0> <Nodes.InNode.InNode object at 0x000001E1997FDC10>
# 41 41
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8E10> <Nodes.SensorNode.SensorNode object at 0x000001E199C7E610>
# 40 40
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8C50> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199C7E750>
# 39 39
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8A90> <Nodes.SensorNode.SensorNode object at 0x000001E19984A890>
# 38 38
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB88D0> <Nodes.OutNode.OutNode object at 0x000001E199C7DB50>
# 37 37
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8750> <Nodes.OutNode.OutNode object at 0x000001E199C72010>
# 36 36
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8590> <Nodes.SensorNode.SensorNode object at 0x000001E199C73350>
# 35 35
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB83D0> <Nodes.SensorNode.SensorNode object at 0x000001E199C718D0>
# 34 34
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8210> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199780250>
# 33 33
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB8050> <Nodes.SensorNode.SensorNode object at 0x000001E197723CD0>
# 32 32
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3E50> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E196E62310>
# 31 31
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3B10> <Nodes.SensorNode.SensorNode object at 0x000001E1976BAED0>
# 30 30
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3A90> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1973BE450>
# 29 29
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3910> <Nodes.SensorNode.SensorNode object at 0x000001E1977354D0>
# 28 28
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3750> <Nodes.OutNode.OutNode object at 0x000001E19984AF50>
# 27 27
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3550> <Nodes.InNode.InNode object at 0x000001E1977261D0>
# 26 26
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3390> <Nodes.SensorNode.SensorNode object at 0x000001E1997D5850>
# 25 25
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB31D0> <Nodes.SensorNode.SensorNode object at 0x000001E197743010>
# 24 24
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB3010> <Nodes.SensorNode.SensorNode object at 0x000001E199C5F750>
# 23 23
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2E50> <Nodes.SensorNode.SensorNode object at 0x000001E1997F1D10>
# 22 22
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2C90> <Nodes.SensorNode.SensorNode object at 0x000001E199C80850>
# 21 21
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2AD0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E19772C590>
# 20 20
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2950> <Nodes.SensorNode.SensorNode object at 0x000001E19765DA10>
# 19 19
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2790> <Nodes.OutNode.OutNode object at 0x000001E197734B90>
# 18 18
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB25D0> <Nodes.OutNode.OutNode object at 0x000001E197734F90>
# 17 17
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2410> <Nodes.InNode.InNode object at 0x000001E1977347D0>
# 16 16
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2250> <Nodes.InNode.InNode object at 0x000001E197734210>
# 15 15
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB2090> <Nodes.InNode.InNode object at 0x000001E197734AD0>
# 14 14
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB1ED0> <Nodes.SensorNode.SensorNode object at 0x000001E19766D9D0>
# 13 13
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB1D10> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1976C6ED0>
# 12 12
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB1B50> <Nodes.SensorNode.SensorNode object at 0x000001E199807D90>
# 11 11
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB1990> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1D7B7A190>
# 10 10
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB1810> <Nodes.SensorNode.SensorNode object at 0x000001E1970FE290>
# 9 9
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB1650> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199805CD0>
# 8 8
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB1490> <Nodes.SensorNode.SensorNode object at 0x000001E199806F90>
# 7 7
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB12D0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E199804D50>
# 6 6
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB10D0> <Nodes.SensorNode.SensorNode object at 0x000001E199807BD0>
# 5 5
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199CB0F10> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E19764F4D0>
# 4 4
#
# <Nodes.RelayNode.RelayNode object at 0x000001E197726290> <Nodes.ConnectorNode.ConnectorNode object at 0x000001E1975F2850>
# 3 3
#
# <Nodes.RelayNode.RelayNode object at 0x000001E19983F310> <Nodes.SensorNode.SensorNode object at 0x000001E1997E5410>
# 2 2
#
# <Nodes.RelayNode.RelayNode object at 0x000001E199C806D0> <Nodes.OutNode.OutNode object at 0x000001E19985EF50>
# 1 1

# %%
for node in net.listNodes:
    print(node.energy)
# Out:
# 9974.220561883121
# 10459.263867335145
# 10368.516495698923
# 10800.0
# 10130.647341573156
# 7369.061183598632
# 9783.0377788314
# 2468.4622179240937
# 10036.279977672148
# 10800.0
# 10368.511629484847
# 7100.318611736207
# 10068.882893264872
# 10185.597828360655
# 7251.948161876252
# 9474.194932708593
# 10446.658594733244
# 10203.38825435495
# 10145.50733812864
# 10049.449797247495
# 10326.67714299211
# 8672.257032262864
# 10800.0
# 9426.260604027128
# 10457.211588698874
# 9750.85343032645
# 6337.880703624598
# 10282.052041254083
# 10222.927136000477
# 10454.781294758797
# 10800.0
# 9733.742736556866
# 10800.0
