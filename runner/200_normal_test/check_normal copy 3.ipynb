# %%
# %cd ../..
# Out:
# d:\HUST\WRSN\Load_balancing_problem\load_balance_network
# C:\Users\Nam\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls

# %%
import sys
import os
# sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from physical_env.network.NetworkIO import NetworkIO


netIO = NetworkIO("physical_env/network/network_scenarios/200_normal_3.yaml")
env, net = netIO.makeNetwork()

for node in net.listNodes:
    node.net = net
    node.env = env
# Out:
# Num cluster: 11
# 50
# target 50
# target [<Target.Target object at 0x00000158FF89C910>, <Target.Target object at 0x00000158F7F1E610>, <Target.Target object at 0x00000158B8E59D10>, <Target.Target object at 0x00000158B8EB6E50>, <Target.Target object at 0x00000158B8C9C190>, <Target.Target object at 0x00000158B8DC0D50>, <Target.Target object at 0x00000158B8C8D110>, <Target.Target object at 0x00000158B8C8D150>, <Target.Target object at 0x00000158F9438090>, <Target.Target object at 0x00000158B8D3B8D0>, <Target.Target object at 0x00000158F9439B90>, <Target.Target object at 0x00000158F9439490>, <Target.Target object at 0x00000158B8F51290>, <Target.Target object at 0x00000158B8CA8FD0>, <Target.Target object at 0x00000158B8F71610>, <Target.Target object at 0x00000158B8C9B0D0>, <Target.Target object at 0x00000158F942D950>, <Target.Target object at 0x00000158F942E1D0>, <Target.Target object at 0x00000158F942D290>, <Target.Target object at 0x00000158B8F0C2D0>, <Target.Target object at 0x00000158B8F0D090>, <Target.Target object at 0x00000158B8F0D450>, <Target.Target object at 0x00000158B8FC0250>, <Target.Target object at 0x00000158B8FC0210>, <Target.Target object at 0x00000158B8FC01D0>, <Target.Target object at 0x00000158B8FC02D0>, <Target.Target object at 0x00000158B8FC0150>, <Target.Target object at 0x00000158B8FC0350>, <Target.Target object at 0x00000158B8FC0550>, <Target.Target object at 0x00000158B8FC0110>, <Target.Target object at 0x00000158B8FC0390>, <Target.Target object at 0x00000158B8FC03D0>, <Target.Target object at 0x00000158B8FC0510>, <Target.Target object at 0x00000158B8FC04D0>, <Target.Target object at 0x00000158B8FC0050>, <Target.Target object at 0x00000158B8FC0290>, <Target.Target object at 0x00000158B8FC05D0>, <Target.Target object at 0x00000158B8FC0490>, <Target.Target object at 0x00000158B8FC00D0>, <Target.Target object at 0x00000158B8FC0850>, <Target.Target object at 0x00000158B8FC0450>, <Target.Target object at 0x00000158B8FC06D0>, <Target.Target object at 0x00000158B8FC0710>, <Target.Target object at 0x00000158B8FC0810>, <Target.Target object at 0x00000158B8FC0410>, <Target.Target object at 0x00000158B8FC0090>, <Target.Target object at 0x00000158B8FC0590>, <Target.Target object at 0x00000158B8FC08D0>, <Target.Target object at 0x00000158B8FC07D0>, <Target.Target object at 0x00000158B8FC0610>]
# target
# [[1, 3], [8, 5], [4, 3], [7, 4], [9, 5], [5, 4], [0, 3], [10, 5], [3, 4], [2, 8], [6, 6]]
# Common point:  [[1, [10, 2, 6]], [8, [3]], [4, [6]], [7, [2]], [9, [2, 10]], [5, [6]], [0, []], [10, [6]], [3, []], [2, []], [6, []]]
# Số target tải mỗi cluster
# [[1, 3], [8, 5], [4, 3], [7, 4], [9, 5], [5, 4], [0, 3], [10, 8], [3, 9], [2, 5.5], [6, 7.25]]

# %%
import matplotlib.pyplot as plt
import numpy as np
# from moviepy.editor import ImageSequenceClip
from IPython.display import Video, display

plt.figure() 
image_files = []

# colors = ['red', 'blue', 'yellow', 'green', 'purple', 'pink', 'brown', 'cyan', 'magenta', 'lime', 'teal', 'lavender', 'maroon', 'olive', 'navy', 'beige', 'indigo', 'turquoise']
shapes = ['<', '>', 's', 'p', 'x', '*', '^', 'v', 'h', 's', 'p', 'o']
colors = ['aliceblue', 'antiquewhite', 'aqua', 'aquamarine', 'azure', 'beige', 'bisque', 'green', 'blanchedalmond', 'blue', 'blueviolet', 'brown', 'burlywood', 'cadetblue', 'chartreuse', 'chocolate', 'coral', 'cornflowerblue', 'cornsilk', 'crimson', 'cyan', 'darkblue', 'darkcyan', 'darkgoldenrod', 'darkgray', 'darkgreen', 'darkgrey', 'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange', 'darkorchid', 'darkred', 'darksalmon', 'darkseagreen', 'darkslateblue', 'darkslategray', 'darkslategrey', 'darkturquoise', 'darkviolet', 'deeppink', 'deepskyblue', 'dimgray', 'dimgrey', 'dodgerblue', 'firebrick', 'floralwhite', 'forestgreen', 'fuchsia', 'gainsboro', 'ghostwhite', 'gold', 'goldenrod', 'gray', 'green', 'greenyellow', 'grey', 'honeydew', 'hotpink', 'indianred', 'indigo', 'ivory', 'khaki', 'lavender', 'lavenderblush', 'lawngreen', 'lemonchiffon', 'lightblue', 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue', 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'lime', 'limegreen', 'linen', 'magenta', 'maroon', 'mediumaquamarine', 'mediumblue', 'mediumorchid', 'mediumpurple', 'mediumseagreen', 'mediumslateblue', 'mediumspringgreen', 'mediumturquoise', 'mediumvioletred', 'midnightblue', 'mintcream', 'mistyrose', 'moccasin']

# def draw(path_to_save_image):
def draw():
    plt.figure(figsize=(9, 9))
    plt.scatter(net.baseStation.location[0], net.baseStation.location[1], marker= "*", color = "purple",s = 200)
    for i in range(len(net.targets_active)):
      if net.targets_active[i] == 0:
        plt.scatter(net.listTargets[i].location[0], net.listTargets[i].location[1], color="red", marker="*",s = 200)
      else:
        plt.scatter(net.listTargets[i].location[0], net.listTargets[i].location[1], color="blue", marker="*") 
    # print(net.targets_active)

         
    
    for cluster in net.listClusters:
    #  plt.scatter(cluster.centroid[0],cluster.centroid[1],color = "black")
     for node in cluster.listNodes:
        x = node.location[0]
        y = node.location[1]
        size = 20
        color = colors[cluster.id]
        type_node = node.__class__.__name__
        if(type_node == "InNode"): marker_ = shapes[0]
        if(type_node == "OutNode"):  marker_ = shapes[1]
        if(type_node == "SensorNode"): marker_ = shapes[2]
        if(type_node == "ConnectorNode"):  marker_ = shapes[3]
        if(node.status == 0): 
          size = 30
          color = "black"

        plt.scatter(x, y, color = color , marker = marker_,s=size)
        # label = str(round(node.energy/node.capacity*100,2))  +"|"+  str(node.id)
        label = str(round(node.energy/node.capacity*100,2))
        # plt.text(x, y, label, ha='center', va='center', fontsize=6, color='black')
          
    relayNodes = [node for node in net.listNodes if node.__class__.__name__ == "RelayNode"]
    for node in relayNodes:
      color = 'orange' 
      size = 20
      x = node.location[0]
      y = node.location[1]
      if(node.status == 0): 
          size = 30
          color = "black"
      plt.scatter(x, y, color = color , marker = 'o',s=size)
      
    #   label =  str(round(node.energy/node.capacity*100,2)) +"|" +  str(node.id)
    
      label =  str(round(node.energy/node.capacity*100,2)) 
      # plt.text(x, y,label, ha='center',va = "center", fontsize=6, color='black')
    plt.show()
    # plt.savefig()


path_prefix = "result/images"     

def log(net, mcs):
    
    while True:

        if net.env.now%10 == 0:
           path = path_prefix +"/" +str(net.env.now) + ".png"
          #  draw(path) 
        print(net.env.now,net.check_nodes(),net.check_targets())
       
        yield net.env.timeout(20.0) 

# netIO = NetworkIO("physical_env/network/network_scenarios/hanoi1000n150.yaml")
# env, net = netIO.makeNetwork()

# for node in net.listNodes:
#     node.net = net
#     node.env = env
print("list clusters",len(net.listClusters))
print("list nodes",len(net.listNodes))

draw()

     
x = env.process(net.operate())
env.process(log(net, None))
env.run(until=x)

   
draw()
# Out:
# list clusters 11
# list nodes 145
# 0 0 0
# 20.0 0 1
# 40.0 0 1
# 60.0 0 1
# 80.0 0 1
# 100.0 0 1
# 120.0 0 1
# 140.0 0 1
# 160.0 0 1
# 180.0 0 1
# 200.0 0 1
# 220.0 0 1
# 240.0 0 1
# 260.0 0 1
# 280.0 0 1
# 300.0 0 1
# 320.0 0 1
# 340.0 0 1
# 360.0 0 1
# 380.0 0 1
# 400.0 0 1
# 420.0 0 1
# 440.0 0 1
# 460.0 0 1
# 480.0 0 1
# 500.0 0 1
# 520.0 0 1
# 540.0 0 1
# 560.0 0 1
# 580.0 0 1
# 600.0 0 1
# 620.0 0 1
# 640.0 0 1
# 660.0 0 1
# 680.0 0 1
# 700.0 0 1
# 720.0 0 1
# 740.0 0 1
# 760.0 0 1
# 780.0 0 1
# 800.0 0 1
# 820.0 0 1
# 840.0 0 1
# 860.0 0 1
# 880.0 0 1
# 900.0 0 1
# 920.0 0 1
# 940.0 0 1
# 960.0 0 1
# 980.0 0 1
# 1000.0 0 1
# 1020.0 0 1
# 1040.0 0 1
# 1060.0 0 1
# 1080.0 0 1
# 1100.0 0 1
# 1120.0 0 1
# 1140.0 0 1
# 1160.0 0 1
# 1180.0 0 1
# 1200.0 0 1
# 1220.0 0 1
# 1240.0 0 1
# 1260.0 0 1
# 1280.0 0 1
# 1300.0 0 1
# 1320.0 0 1
# 1340.0 0 1
# 1360.0 0 1
# 1380.0 0 1
# 1400.0 0 1
# 1420.0 0 1
# 1440.0 0 1
# 1460.0 0 1
# 1480.0 0 1
# 1500.0 0 1
# 1520.0 0 1
# 1540.0 0 1
# 1560.0 0 1
# 1580.0 0 1
# 1600.0 0 1
# 1620.0 0 1
# 1640.0 0 1
# 1660.0 0 1
# 1680.0 0 1
# 1700.0 0 1
# 1720.0 0 1
# 1740.0 0 1
# 1760.0 0 1
# 1780.0 0 1
# 1800.0 0 1
# 1820.0 0 1
# 1840.0 0 1
# 1860.0 0 1
# 1880.0 0 1
# 1900.0 0 1
# 1920.0 0 1
# 1940.0 0 1
# 1960.0 0 1
# 1980.0 0 1
# 2000.0 0 1
# 2020.0 0 1
# 2040.0 0 1
# 2060.0 0 1
# 2080.0 0 1
# 2100.0 0 1
# 2120.0 0 1
# 2140.0 0 1
# 2160.0 0 1
# 2180.0 0 1
# 2200.0 0 1
# 2220.0 0 1
# 2240.0 0 1
# 2260.0 0 1
# 2280.0 0 1
# 2300.0 0 1
# 2320.0 0 1
# 2340.0 0 1
# 2360.0 0 1
# 2380.0 0 1
# 2400.0 0 1
# 2420.0 0 1
# 2440.0 0 1
# 2460.0 0 1
# 2480.0 0 1
# 2500.0 0 1
# 2520.0 0 1
# 2540.0 0 1
# 2560.0 0 1
# 2580.0 0 1
# 2600.0 0 1
# 2620.0 0 1
# 2640.0 0 1
# 2660.0 0 1
# 2680.0 0 1
# 2700.0 0 1
# 2720.0 0 1
# 2740.0 0 1
# 2760.0 0 1
# 2780.0 0 1
# 2800.0 0 1
# 2820.0 0 1
# 2840.0 0 1
# 2860.0 0 1
# 2880.0 0 1
# 2900.0 0 1
# 2920.0 0 1
# 2940.0 0 1
# 2960.0 0 1
# 2980.0 0 1
# 3000.0 0 1
# 3020.0 0 1
# 3040.0 0 1
# 3060.0 0 1
# 3080.0 0 1
# 3100.0 0 1
# 3120.0 0 1
# 3140.0 0 1
# 3160.0 0 1
# 3180.0 0 1
# 3200.0 0 1
# 3220.0 0 1
# 3240.0 0 1
# 3260.0 0 1
# 3280.0 0 1
# 3300.0 0 1
# 3320.0 0 1
# 3340.0 0 1
# 3360.0 0 1
# 3380.0 0 1
# 3400.0 0 1
# 3420.0 0 1
# 3440.0 0 1
# 3460.0 0 1
# 3480.0 0 1
# 3500.0 0 1
# 3520.0 0 1
# 3540.0 0 1
# 3560.0 0 1
# 3580.0 0 1
# 3600.0 0 1
# 3620.0 0 1
# 3640.0 0 1
# 3660.0 0 1
# 3680.0 0 1
# 3700.0 0 1
# 3720.0 0 1
# 3740.0 0 1
# 3760.0 0 1
# 3780.0 0 1
# 3800.0 0 1
# 3820.0 0 1
# 3840.0 0 1
# 3860.0 0 1
# 3880.0 0 1
# 3900.0 0 1
# 3920.0 0 1
# 3940.0 0 1
# 3960.0 0 1
# 3980.0 0 1
# 4000.0 0 1
# 4020.0 0 1
# 4040.0 0 1
# 4060.0 0 1
# 4080.0 0 1
# 4100.0 0 1
# 4120.0 0 1
# 4140.0 0 1
# 4160.0 0 1
# 4180.0 0 1
# 4200.0 0 1
# 4220.0 0 1
# 4240.0 0 1
# 4260.0 0 1
# 4280.0 0 1
# 4300.0 0 1
# 4320.0 0 1
# 4340.0 0 1
# 4360.0 0 1
# 4380.0 0 1
# 4400.0 0 1
# 4420.0 0 1
# 4440.0 0 1
# 4460.0 0 1
# 4480.0 0 1
# 4500.0 0 1
# 4520.0 0 1
# 4540.0 0 1
# 4560.0 0 1
# 4580.0 0 1
# 4600.0 0 1
# 4620.0 0 1
# 4640.0 0 1
# 4660.0 0 1
# 4680.0 0 1
# 4700.0 0 1
# 4720.0 0 1
# 4740.0 0 1
# 4760.0 0 1
# 4780.0 0 1
# 4800.0 0 1
# 4820.0 0 1
# 4840.0 0 1
# 4860.0 0 1
# 4880.0 0 1
# 4900.0 0 1
# 4920.0 0 1
# 4940.0 0 1
# 4960.0 0 1
# 4980.0 0 1
# 5000.0 0 1
# 5020.0 0 1
# 5040.0 0 1
# 5060.0 0 1
# 5080.0 0 1
# 5100.0 0 1
# 5120.0 0 1
# 5140.0 0 1
# 5160.0 0 1
# 5180.0 0 1
# 5200.0 0 1
# 5220.0 0 1
# 5240.0 0 1
# 5260.0 0 1
# 5280.0 0 1
# 5300.0 0 1
# 5320.0 0 1
# 5340.0 0 1
# 5360.0 0 1
# 5380.0 0 1
# 5400.0 0 1
# 5420.0 0 1
# 5440.0 0 1
# 5460.0 0 1
# 5480.0 0 1
# 5500.0 0 1
# 5520.0 0 1
# 5540.0 0 1
# 5560.0 0 1
# 5580.0 0 1
# 5600.0 0 1
# 5620.0 0 1
# 5640.0 0 1
# 5660.0 0 1
# 5680.0 0 1
# 5700.0 0 1
# 5720.0 0 1
# 5740.0 0 1
# 5760.0 0 1
# 5780.0 0 1
# 5800.0 0 1
# 5820.0 0 1
# 5840.0 0 1
# 5860.0 0 1
# 5880.0 0 1
# 5900.0 0 1
# 5920.0 0 1
# 5940.0 0 1
# 5960.0 0 1
# 5980.0 0 1
# 6000.0 0 1
# 6020.0 0 1
# 6040.0 0 1
# 6060.0 0 1
# 6080.0 0 1
# 6100.0 0 1
# 6120.0 0 1
# 6140.0 0 1
# 6160.0 0 1
# 6180.0 0 1
# 6200.0 0 1
# 6220.0 0 1
# 6240.0 0 1
# 6260.0 0 1
# 6280.0 0 1
# 6300.0 0 1
# 6320.0 0 1
# 6340.0 0 1
# 6360.0 0 1
# 6380.0 0 1
# 6400.0 0 1
# 6420.0 0 1
# 6440.0 0 1
# 6460.0 0 1
# 6480.0 0 1
# 6500.0 0 1
# 6520.0 0 1
# 6540.0 0 1
# 6560.0 0 1
# 6580.0 0 1
# 6600.0 0 1
# 6620.0 0 1
# 6640.0 0 1
# 6660.0 0 1
# 6680.0 0 1
# 6700.0 0 1
# 6720.0 0 1
# 6740.0 0 1
# 6760.0 0 1
# 6780.0 0 1
# 6800.0 0 1
# 6820.0 0 1
# 6840.0 0 1
# 6860.0 0 1
# 6880.0 0 1
# 6900.0 0 1
# 6920.0 0 1
# 6940.0 0 1
# 6960.0 0 1
# 6980.0 0 1
# 7000.0 0 1
# 7020.0 0 1
# 7040.0 0 1
# 7060.0 0 1
# 7080.0 0 1
# 7100.0 0 1
# 7120.0 0 1
# 7140.0 0 1
# 7160.0 0 1
# 7180.0 0 1
# 7200.0 0 1
# 7220.0 0 1
# 7240.0 0 1
# 7260.0 0 1
# 7280.0 0 1
# 7300.0 0 1
# 7320.0 0 1
# 7340.0 0 1
# 7360.0 0 1
# 7380.0 0 1
# 7400.0 0 1
# 7420.0 0 1
# 7440.0 0 1
# 7460.0 0 1
# 7480.0 0 1
# 7500.0 0 1
# 7520.0 0 1
# 7540.0 0 1
# 7560.0 0 1
# 7580.0 0 1
# 7600.0 0 1
# 7620.0 0 1
# 7640.0 0 1
# 7660.0 0 1
# 7680.0 0 1
# 7700.0 0 1
# 7720.0 0 1
# 7740.0 0 1
# 7760.0 0 1
# 7780.0 0 1
# 7800.0 0 1
# 7820.0 0 1
# 7840.0 0 1
# 7860.0 0 1
# 7880.0 0 1
# 7900.0 0 1
# 7920.0 0 1
# 7940.0 0 1
# 7960.0 0 1
# 7980.0 0 1
# 8000.0 0 1
# 8020.0 0 1
# 8040.0 0 1
# 8060.0 0 1
# 8080.0 0 1
# 8100.0 0 1
# 8120.0 0 1
# 8140.0 0 1
# 8160.0 0 1
# 8180.0 0 1
# 8200.0 0 1
# 8220.0 0 1
# 8240.0 0 1
# 8260.0 0 1
# 8280.0 0 1
# 8300.0 0 1
# 8320.0 0 1
# 8340.0 0 1
# 8360.0 0 1
# 8380.0 0 1
# 8400.0 0 1
# 8420.0 0 1
# 8440.0 0 1
# 8460.0 0 1
# 8480.0 0 1
# 8500.0 0 1
# 8520.0 0 1
# 8540.0 0 1
# 8560.0 0 1
# 8580.0 0 1
# 8600.0 0 1
# 8620.0 0 1
# 8640.0 0 1
# 8660.0 0 1
# 8680.0 0 1
# 8700.0 0 1
# 8720.0 0 1
# 8740.0 0 1
# 8760.0 0 1
# 8780.0 0 1
# 8800.0 0 1
# 8820.0 0 1
# 8840.0 0 1
# 8860.0 0 1
# 8880.0 0 1
# 8900.0 0 1
# 8920.0 0 1
# 8940.0 0 1
# 8960.0 0 1
# 8980.0 0 1
# 9000.0 0 1
# 9020.0 0 1
# 9040.0 0 1
# 9060.0 0 1
# 9080.0 0 1
# 9100.0 0 1
# 9120.0 0 1
# 9140.0 0 1
# 9160.0 0 1
# 9180.0 0 1
# 9200.0 0 1
# 9220.0 0 1
# 9240.0 0 1
# 9260.0 0 1
# 9280.0 0 1
# 9300.0 0 1
# 9320.0 0 1
# 9340.0 0 1
# 9360.0 0 1
# 9380.0 0 1
# 9400.0 0 1
# 9420.0 0 1
# 9440.0 0 1
# 9460.0 0 1
# 9480.0 0 1
# 9500.0 0 1
# 9520.0 0 1
# 9540.0 0 1
# 9560.0 0 1
# 9580.0 0 1
# 9600.0 0 1
# 9620.0 0 1
# 9640.0 0 1
# 9660.0 0 1
# 9680.0 0 1
# 9700.0 0 1
# 9720.0 0 1
# 9740.0 0 1
# 9760.0 0 1
# 9780.0 0 1
# 9800.0 0 1
# 9820.0 0 1
# 9840.0 0 1
# 9860.0 0 1
# 9880.0 0 1
# 9900.0 0 1
# 9920.0 0 1
# 9940.0 0 1
# 9960.0 0 1
# 9980.0 0 1
# 10000.0 0 1
# 10020.0 0 1
# 10040.0 0 1
# 10060.0 0 1
# 10080.0 0 1
# 10100.0 0 1
# 10120.0 0 1
# 10140.0 0 1
# 10160.0 0 1
# 10180.0 0 1
# 10200.0 0 1
# 10220.0 0 1
# 10240.0 0 1
# 10260.0 0 1
# 10280.0 0 1
# 10300.0 0 1
# 10320.0 0 1
# 10340.0 0 1
# 10360.0 0 1
# 10380.0 0 1
# 10400.0 0 1
# 10420.0 0 1
# 10440.0 0 1
# 10460.0 0 1
# 10480.0 0 1
# 10500.0 0 1
# 10520.0 0 1
# 10540.0 0 1
# 10560.0 0 1
# 10580.0 0 1
# 10600.0 0 1
# 10620.0 0 1
# 10640.0 0 1
# 10660.0 0 1
# 10680.0 0 1
# 10700.0 0 1
# 10720.0 0 1
# 10740.0 0 1
# 10760.0 0 1
# 10780.0 0 1
# 10800.0 0 1
# 10820.0 0 1
# 10840.0 0 1
# 10860.0 0 1
# 10880.0 0 1
# 10900.0 0 1
# 10920.0 0 1
# 10940.0 0 1
# 10960.0 0 1
# 10980.0 0 1
# 11000.0 0 1
# 11020.0 0 1
# 11040.0 0 1
# 11060.0 0 1
# 11080.0 0 1
# 11100.0 0 1
# 11120.0 0 1
# 11140.0 0 1
# 11160.0 0 1
# 11180.0 0 1
# 11200.0 0 1
# 11220.0 0 1
# 11240.0 0 1
# 11260.0 0 1
# 11280.0 0 1
# 11300.0 0 1
# 11320.0 0 1
# 11340.0 0 1
# 11360.0 0 1
# 11380.0 0 1
# 11400.0 0 1
# 11420.0 0 1
# 11440.0 0 1
# 11460.0 0 1
# 11480.0 0 1
# 11500.0 0 1
# 11520.0 0 1
# 11540.0 0 1
# 11560.0 0 1
# 11580.0 0 1
# 11600.0 0 1
# 11620.0 0 1
# 11640.0 0 1
# 11660.0 0 1
# 11680.0 0 1
# 11700.0 0 1
# 11720.0 0 1
# 11740.0 0 1
# 11760.0 0 1
# 11780.0 0 1
# 11800.0 0 1
# 11820.0 0 1
# 11840.0 0 1
# 11860.0 0 1
# 11880.0 0 1
# 11900.0 0 1
# 11920.0 0 1
# 11940.0 0 1
# 11960.0 0 1
# 11980.0 0 1
# 12000.0 0 1
# 12020.0 0 1
# 12040.0 0 1
# 12060.0 0 1
# 12080.0 0 1
# 12100.0 0 1
# 12120.0 0 1
# 12140.0 0 1
# 12160.0 0 1
# 12180.0 0 1
# 12200.0 0 1
# 12220.0 0 1
# 12240.0 0 1
# 12260.0 0 1
# 12280.0 0 1
# 12300.0 0 1
# 12320.0 0 1
# 12340.0 0 1
# 12360.0 0 1
# 12380.0 0 1
# 12400.0 0 1
# 12420.0 0 1
# 12440.0 0 1
# 12460.0 0 1
# 12480.0 0 1
# 12500.0 0 1
# 12520.0 0 1
# 12540.0 0 1
# 12560.0 0 1
# 12580.0 0 1
# 12600.0 0 1
# 12620.0 0 1
# 12640.0 0 1
# 12660.0 0 1
# 12680.0 0 1
# 12700.0 0 1
# 12720.0 0 1
# 12740.0 0 1
# 12760.0 0 1
# 12780.0 0 1
# 12800.0 0 1
# 12820.0 0 1
# 12840.0 0 1
# 12860.0 0 1
# 12880.0 0 1
# 12900.0 0 1
# 12920.0 0 1
# 12940.0 0 1
# 12960.0 0 1
# 12980.0 0 1
# 13000.0 0 1
# 13020.0 0 1
# 13040.0 0 1
# 13060.0 0 1
# 13080.0 0 1
# 13100.0 0 1
# 13120.0 0 1
# 13140.0 0 1
# 13160.0 0 1
# 13180.0 0 1
# 13200.0 0 1
# 13220.0 0 1
# 13240.0 0 1
# 13260.0 0 1
# 13280.0 0 1
# 13300.0 0 1
# 13320.0 0 1
# 13340.0 0 1
# 13360.0 0 1
# 13380.0 0 1
# 13400.0 0 1
# 13420.0 0 1
# 13440.0 0 1
# 13460.0 0 1
# 13480.0 0 1
# 13500.0 0 1
# 13520.0 0 1
# 13540.0 0 1
# 13560.0 0 1
# 13580.0 0 1
# 13600.0 0 1
# 13620.0 0 1
# 13640.0 0 1
# 13660.0 0 1
# 13680.0 0 1
# 13700.0 0 1
# 13720.0 0 1
# 13740.0 0 1
# 13760.0 0 1
# 13780.0 0 1
# 13800.0 0 1
# 13820.0 0 1
# 13840.0 0 1
# 13860.0 0 1
# 13880.0 0 1
# 13900.0 0 1
# 13920.0 0 1
# 13940.0 0 1
# 13960.0 0 1
# 13980.0 0 1
# 14000.0 0 1
# 14020.0 0 1
# 14040.0 0 1
# 14060.0 0 1
# 14080.0 0 1
# 14100.0 0 1
# 14120.0 0 1
# 14140.0 0 1
# 14160.0 0 1
# 14180.0 0 1
# 14200.0 0 1
# 14220.0 0 1
# 14240.0 0 1
# 14260.0 0 1
# 14280.0 0 1
# 14300.0 0 1
# 14320.0 0 1
# 14340.0 0 1
# 14360.0 0 1
# 14380.0 0 1
# 14400.0 0 1
# 14420.0 0 1
# 14440.0 0 1
# 14460.0 0 1
# 14480.0 0 1
# 14500.0 0 1
# 14520.0 0 1
# 14540.0 0 1
# 14560.0 0 1
# 14580.0 0 1
# 14600.0 0 1
# 14620.0 0 1
# 14640.0 0 1
# 14660.0 0 1
# 14680.0 0 1
# 14700.0 0 1
# 14720.0 0 1
# 14740.0 0 1
# 14760.0 0 1
# 14780.0 0 1
# 14800.0 0 1
# 14820.0 0 1
# 14840.0 0 1
# 14860.0 0 1
# 14880.0 0 1
# 14900.0 0 1
# 14920.0 0 1
# 14940.0 0 1
# 14960.0 0 1
# 14980.0 0 1
# 15000.0 0 1
# 15020.0 0 1
# 15040.0 0 1
# 15060.0 0 1
# 15080.0 0 1
# 15100.0 0 1
# 15120.0 0 1
# 15140.0 0 1
# 15160.0 0 1
# 15180.0 0 1
# 15200.0 0 1
# 15220.0 0 1
# 15240.0 0 1
# 15260.0 0 1
# 15280.0 0 1
# 15300.0 0 1
# 15320.0 0 1
# 15340.0 0 1
# 15360.0 0 1
# 15380.0 0 1
# 15400.0 0 1
# 15420.0 0 1
# 15440.0 0 1
# 15460.0 0 1
# 15480.0 0 1
# 15500.0 0 1
# 15520.0 0 1
# 15540.0 0 1
# 15560.0 0 1
# 15580.0 0 1
# 15600.0 0 1
# 15620.0 0 1
# 15640.0 0 1
# 15660.0 0 1
# 15680.0 0 1
# 15700.0 0 1
# 15720.0 0 1
# 15740.0 0 1
# 15760.0 0 1
# 15780.0 0 1
# 15800.0 0 1
# 15820.0 0 1
# 15840.0 0 1
# 15860.0 0 1
# 15880.0 0 1
# 15900.0 0 1
# 15920.0 0 1
# 15940.0 0 1
# 15960.0 0 1
# 15980.0 0 1
# 16000.0 0 1
# 16020.0 0 1
# 16040.0 0 1
# 16060.0 0 1
# 16080.0 0 1
# 16100.0 0 1
# 16120.0 0 1
# 16140.0 0 1
# 16160.0 0 1
# 16180.0 0 1
# 16200.0 0 1
# 16220.0 0 1
# 16240.0 0 1
# 16260.0 0 1
# 16280.0 0 1
# 16300.0 0 1
# 16320.0 0 1
# 16340.0 0 1
# 16360.0 0 1
# 16380.0 0 1
# 16400.0 0 1
# 16420.0 0 1
# 16440.0 0 1
# 16460.0 0 1
# 16480.0 0 1
# 16500.0 0 1
# 16520.0 0 1
# 16540.0 0 1
# 16560.0 0 1
# 16580.0 0 1
# 16600.0 0 1
# 16620.0 0 1
# 16640.0 0 1
# 16660.0 0 1
# 16680.0 0 1
# 16700.0 0 1
# 16720.0 0 1
# 16740.0 0 1
# 16760.0 0 1
# 16780.0 0 1
# 16800.0 0 1
# 16820.0 0 1
# 16840.0 0 1
# 16860.0 0 1
# 16880.0 0 1
# 16900.0 0 1
# 16920.0 0 1
# 16940.0 0 1
# 16960.0 0 1
# 16980.0 0 1
# 17000.0 0 1
# 17020.0 0 1
# 17040.0 0 1
# 17060.0 0 1
# 17080.0 0 1
# 17100.0 0 1
# 17120.0 0 1
# 17140.0 0 1
# 17160.0 0 1
# 17180.0 0 1
# 17200.0 0 1
# 17220.0 0 1
# 17240.0 0 1
# 17260.0 0 1
# 17280.0 0 1
# 17300.0 0 1
# 17320.0 0 1
# 17340.0 0 1
# 17360.0 0 1
# 17380.0 0 1
# 17400.0 0 1
# 17420.0 0 1
# 17440.0 0 1
# 17460.0 0 1
# 17480.0 0 1
# 17500.0 0 1
# 17520.0 0 1
# 17540.0 0 1
# 17560.0 0 1
# 17580.0 0 1
# 17600.0 0 1
# 17620.0 0 1
# 17640.0 0 1
# 17660.0 0 1
# 17680.0 0 1
# 17700.0 0 1
# 17720.0 0 1
# 17740.0 0 1
# 17760.0 0 1
# 17780.0 0 1
# 17800.0 0 1
# 17820.0 0 1
# 17840.0 0 1
# 17860.0 0 1
# 17880.0 0 1
# 17900.0 0 1
# 17920.0 0 1
# 17940.0 0 1
# 17960.0 0 1
# Network dies
# 17979.0 2 0

# %%
net.targets_active
for node in net.listNodes:
    if node.status == 0:
        print(node.__class__.__name__)

for a in net.targets_active:
    if a == 0:
        print(a)
# Out:
# OutNode
# RelayNode
# 0
# 0
# 0
# 0
# 0

# %%
for node1 in net.listNodes:
    for node2 in net.listNodes:
        if node1.id == node2.id and node1.__class__.__name__ != node2.__class__.__name__:
            print(node1,node2)
            print(node1.id, node2.id)
            print()
# Out:
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7CAB10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DBBD0>
# 61 61
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7CA950> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DBA10>
# 60 60
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7CA750> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB850>
# 59 59
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7CA590> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB690>
# 58 58
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7CA450> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB4D0>
# 57 57
#
# <Nodes.OutNode.OutNode object at 0x00000158BB7CA290> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB310>
# 56 56
#
# <Nodes.OutNode.OutNode object at 0x00000158BB7CA0D0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB150>
# 55 55
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9F10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DAF90>
# 54 54
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9D90> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DADD0>
# 53 53
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9BD0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DAC10>
# 52 52
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7C9A10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA950>
# 51 51
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7C9850> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA8D0>
# 50 50
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9610> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA710>
# 49 49
#
# <Nodes.OutNode.OutNode object at 0x00000158BB7C9410> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA550>
# 48 48
#
# <Nodes.InNode.InNode object at 0x00000158BB7C9210> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA350>
# 47 47
#
# <Nodes.InNode.InNode object at 0x00000158BB7C9010> <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA190>
# 46 46
#
# <Nodes.InNode.InNode object at 0x00000158BB7C8E10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9FD0>
# 45 45
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7C8C50> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9E10>
# 44 44
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB7C8A10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9C50>
# 43 43
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB019590> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9A90>
# 42 42
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB0BFB90> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D98D0>
# 41 41
#
# <Nodes.OutNode.OutNode object at 0x00000158BB0E6D50> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9710>
# 40 40
#
# <Nodes.OutNode.OutNode object at 0x00000158BB0E6750> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9550>
# 39 39
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB0E61D0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9390>
# 38 38
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0E4910> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D91D0>
# 37 37
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB0786D0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9010>
# 36 36
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB04BFD0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8E50>
# 35 35
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB048BD0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8CD0>
# 34 34
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB0E0250> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8B10>
# 33 33
#
# <Nodes.OutNode.OutNode object at 0x00000158BB0EA090> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8950>
# 32 32
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0E8FD0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8790>
# 31 31
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB056D10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D85D0>
# 30 30
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB06F690> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D83D0>
# 29 29
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB030F50> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8210>
# 28 28
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB063390> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8050>
# 27 27
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8F8B590> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3E50>
# 26 26
#
# <Nodes.OutNode.OutNode object at 0x00000158BB00BC50> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3C90>
# 25 25
#
# <Nodes.InNode.InNode object at 0x00000158B8FB0A90> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3AD0>
# 24 24
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8FB3450> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3950>
# 23 23
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8F57610> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3790>
# 22 22
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158B8F57A90> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D35D0>
# 21 21
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8FC6A50> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D33D0>
# 20 20
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0D4AD0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3210>
# 19 19
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8FC23D0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3050>
# 18 18
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158B8F8B2D0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2E90>
# 17 17
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8F8ABD0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2CD0>
# 16 16
#
# <Nodes.OutNode.OutNode object at 0x00000158BB0CE790> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2B10>
# 15 15
#
# <Nodes.InNode.InNode object at 0x00000158BB0F8850> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2990>
# 14 14
#
# <Nodes.InNode.InNode object at 0x00000158BB03FAD0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D27D0>
# 13 13
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB03C810> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2610>
# 12 12
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB03E410> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2450>
# 11 11
#
# <Nodes.SensorNode.SensorNode object at 0x00000158F9442810> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2290>
# 10 10
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0AA890> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2110>
# 9 9
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0AB3D0> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1F50>
# 8 8
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB0AA950> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1D90>
# 7 7
#
# <Nodes.OutNode.OutNode object at 0x00000158BB0A9610> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1BD0>
# 6 6
#
# <Nodes.SensorNode.SensorNode object at 0x00000158BB0A9D50> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D19D0>
# 5 5
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8FCDA10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1810>
# 4 4
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x00000158B8FCCF10> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1650>
# 3 3
#
# <Nodes.SensorNode.SensorNode object at 0x00000158B8E72850> <Nodes.RelayNode.RelayNode object at 0x00000158BB0A4CD0>
# 2 2
#
# <Nodes.OutNode.OutNode object at 0x00000158B86F3790> <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1610>
# 1 1
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DBBD0> <Nodes.SensorNode.SensorNode object at 0x00000158BB7CAB10>
# 61 61
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DBA10> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7CA950>
# 60 60
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB850> <Nodes.SensorNode.SensorNode object at 0x00000158BB7CA750>
# 59 59
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB690> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7CA590>
# 58 58
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB4D0> <Nodes.SensorNode.SensorNode object at 0x00000158BB7CA450>
# 57 57
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB310> <Nodes.OutNode.OutNode object at 0x00000158BB7CA290>
# 56 56
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DB150> <Nodes.OutNode.OutNode object at 0x00000158BB7CA0D0>
# 55 55
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DAF90> <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9F10>
# 54 54
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DADD0> <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9D90>
# 53 53
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DAC10> <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9BD0>
# 52 52
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA950> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7C9A10>
# 51 51
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA8D0> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB7C9850>
# 50 50
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA710> <Nodes.SensorNode.SensorNode object at 0x00000158BB7C9610>
# 49 49
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA550> <Nodes.OutNode.OutNode object at 0x00000158BB7C9410>
# 48 48
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA350> <Nodes.InNode.InNode object at 0x00000158BB7C9210>
# 47 47
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7DA190> <Nodes.InNode.InNode object at 0x00000158BB7C9010>
# 46 46
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9FD0> <Nodes.InNode.InNode object at 0x00000158BB7C8E10>
# 45 45
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9E10> <Nodes.SensorNode.SensorNode object at 0x00000158BB7C8C50>
# 44 44
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9C50> <Nodes.SensorNode.SensorNode object at 0x00000158BB7C8A10>
# 43 43
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9A90> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB019590>
# 42 42
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D98D0> <Nodes.SensorNode.SensorNode object at 0x00000158BB0BFB90>
# 41 41
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9710> <Nodes.OutNode.OutNode object at 0x00000158BB0E6D50>
# 40 40
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9550> <Nodes.OutNode.OutNode object at 0x00000158BB0E6750>
# 39 39
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9390> <Nodes.SensorNode.SensorNode object at 0x00000158BB0E61D0>
# 38 38
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D91D0> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0E4910>
# 37 37
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D9010> <Nodes.SensorNode.SensorNode object at 0x00000158BB0786D0>
# 36 36
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8E50> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB04BFD0>
# 35 35
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8CD0> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB048BD0>
# 34 34
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8B10> <Nodes.SensorNode.SensorNode object at 0x00000158BB0E0250>
# 33 33
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8950> <Nodes.OutNode.OutNode object at 0x00000158BB0EA090>
# 32 32
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8790> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0E8FD0>
# 31 31
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D85D0> <Nodes.SensorNode.SensorNode object at 0x00000158BB056D10>
# 30 30
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D83D0> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB06F690>
# 29 29
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8210> <Nodes.SensorNode.SensorNode object at 0x00000158BB030F50>
# 28 28
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D8050> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB063390>
# 27 27
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3E50> <Nodes.SensorNode.SensorNode object at 0x00000158B8F8B590>
# 26 26
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3C90> <Nodes.OutNode.OutNode object at 0x00000158BB00BC50>
# 25 25
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3AD0> <Nodes.InNode.InNode object at 0x00000158B8FB0A90>
# 24 24
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3950> <Nodes.SensorNode.SensorNode object at 0x00000158B8FB3450>
# 23 23
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3790> <Nodes.SensorNode.SensorNode object at 0x00000158B8F57610>
# 22 22
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D35D0> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158B8F57A90>
# 21 21
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D33D0> <Nodes.SensorNode.SensorNode object at 0x00000158B8FC6A50>
# 20 20
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3210> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0D4AD0>
# 19 19
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D3050> <Nodes.SensorNode.SensorNode object at 0x00000158B8FC23D0>
# 18 18
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2E90> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158B8F8B2D0>
# 17 17
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2CD0> <Nodes.SensorNode.SensorNode object at 0x00000158B8F8ABD0>
# 16 16
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2B10> <Nodes.OutNode.OutNode object at 0x00000158BB0CE790>
# 15 15
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2990> <Nodes.InNode.InNode object at 0x00000158BB0F8850>
# 14 14
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D27D0> <Nodes.InNode.InNode object at 0x00000158BB03FAD0>
# 13 13
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2610> <Nodes.SensorNode.SensorNode object at 0x00000158BB03C810>
# 12 12
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2450> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB03E410>
# 11 11
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2290> <Nodes.SensorNode.SensorNode object at 0x00000158F9442810>
# 10 10
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D2110> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0AA890>
# 9 9
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1F50> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158BB0AB3D0>
# 8 8
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1D90> <Nodes.SensorNode.SensorNode object at 0x00000158BB0AA950>
# 7 7
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1BD0> <Nodes.OutNode.OutNode object at 0x00000158BB0A9610>
# 6 6
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D19D0> <Nodes.SensorNode.SensorNode object at 0x00000158BB0A9D50>
# 5 5
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1810> <Nodes.SensorNode.SensorNode object at 0x00000158B8FCDA10>
# 4 4
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1650> <Nodes.ConnectorNode.ConnectorNode object at 0x00000158B8FCCF10>
# 3 3
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB0A4CD0> <Nodes.SensorNode.SensorNode object at 0x00000158B8E72850>
# 2 2
#
# <Nodes.RelayNode.RelayNode object at 0x00000158BB7D1610> <Nodes.OutNode.OutNode object at 0x00000158B86F3790>
# 1 1

# %%
for node in net.listNodes:
    print(node.energy)
# Out:
# 10273.942039073598
# 10418.758984466702
# 10800.0
# 10060.943166402358
# 10800.0
# 9711.505141597176
# 5401.064106832607
# 9498.150948718103
# 8144.441215970022
# 9577.464983822312
# 10354.573048235925
# 10411.096241187164
# 10138.622793890248
# 5589.409563673999
# 9460.948542296283
# 10382.295849299235
# 9958.117531815122
# 10800.0
# 9782.783258277956
# 4369.5359815330385
# 10800.0
# 10259.390336242355
# 9426.82471288842
# 10158.404209334103
# 10800.0
# 10151.514894350896
# 9530.253256192756
# 10267.953071819993
# 7507.300953175436
# 9438.68019524005
# 9793.835458747108
# 10305.90451510653
# 10362.545993166535
# 10399.842132265634
# 10800.0
# 10276.216995358911
# 3953.882046617
# 8040.950241197513
# 10800.0
# 10800.0
# 10395.373385445026
# 10360.709190435879
# 10800.0
# 10098.437390681507
# 7579.361106441865
# 9483.981190398323
# 10396.637287537216
# 10800.0
# 10115.724822052729
# 10800.0
# 9515.144148118843
# 10250.763338135519
# 6772.23379899722
# 10800.0
# 10311.575077686482
# 9994.570441315773
# 10111.19352254579
# 10800.0
# 10054.67633341281
# 5348.817247082129
# 9471.855311984771
# 10254.68285790533
# 10419.675901578668
# 10800.0
# 10097.893195637145
# 10240.108514647534
# 10031.009753570885
# 9053.691233813995
# 10258.514710774396
# 540
# 7784.269119940047
# 8309.980415942195
# 10422.463254730017
# 10800.0
# 10115.972966387722
# 10800.0
# 9434.629195240157
# 10241.790849636162
# 6993.3785660611775
# 10408.755408458139
# 10392.634072458522
# 9596.382468069925
# 10263.963832923573
# 6814.465308730506
# 3953.882046617
# 540.0163192230024
# 540
# 5348.817247082129
# 5348.817247082129
# 5348.817247082129
# 5348.817247082129
# 4058.7354383538213
# 4058.7354383538213
# 4058.7354383538213
# 4058.7354383538213
# 10800.0
# 10800.0
# 10800.0
# 6814.465308730506
# 6814.465308730506
# 6814.465308730506
# 6814.465308730506
# 6814.465308730506
# 6814.465308730506
# 5546.934808613354
# 5546.934808613354
# 5546.934808613354
# 5546.934808613354
# 5546.934808613354
# 5546.934808613354
# 5546.934808613354
# 10800.0
# 10800.0
# 10800.0
# 10800.0
# 10800.0
# 10799.926805351815
# 10799.926805351815
# 10799.926805351815
# 10799.966805351816
# 10800.0
# 10800.0
# 7204.199999943972
# 4105.85970473928
# 4105.85970473928
# 10799.926879860548
# 10799.926879860548
# 10799.966879860549
# 10800.0
# 10800.0
# 10800.0
# 7923.359999943318
# 5355.023633042762
# 5355.023633042762
# 5355.023633042762
# 8642.519999952907
# 6772.23379899722
# 6772.23379899722
# 7204.199999943972
# 4369.5359815330385
# 4369.5359815330385
# 8642.519999952907
# 6993.3785660611775
# 6993.3785660611775
# 6993.3785660611775
