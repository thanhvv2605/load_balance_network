# %%
# %cd ../..
# Out:
# d:\HUST\WRSN\Load_balancing_problem\load_balance_network
# C:\Users\Nam\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls

# %%
import sys
import os
# sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from physical_env.network.NetworkIO import NetworkIO


netIO = NetworkIO("physical_env/network/network_scenarios/200_normal_4.yaml")
env, net = netIO.makeNetwork()

for node in net.listNodes:
    node.net = net
    node.env = env
# Out:
# Num cluster: 19
# 50
# target 50
# target [<Target.Target object at 0x000001C31507C250>, <Target.Target object at 0x000001C3548E9210>, <Target.Target object at 0x000001C354994E50>, <Target.Target object at 0x000001C354B4C710>, <Target.Target object at 0x000001C3545E3B50>, <Target.Target object at 0x000001C315069A90>, <Target.Target object at 0x000001C315068450>, <Target.Target object at 0x000001C354A11590>, <Target.Target object at 0x000001C3548DDE10>, <Target.Target object at 0x000001C3548AE310>, <Target.Target object at 0x000001C3548DDE50>, <Target.Target object at 0x000001C315063290>, <Target.Target object at 0x000001C31507A7D0>, <Target.Target object at 0x000001C354BDC310>, <Target.Target object at 0x000001C354BDC450>, <Target.Target object at 0x000001C354B9F310>, <Target.Target object at 0x000001C354B9E410>, <Target.Target object at 0x000001C3543C1510>, <Target.Target object at 0x000001C354B253D0>, <Target.Target object at 0x000001C354BDA410>, <Target.Target object at 0x000001C354BDB090>, <Target.Target object at 0x000001C354BDAF50>, <Target.Target object at 0x000001C354BA4E10>, <Target.Target object at 0x000001C353BD5010>, <Target.Target object at 0x000001C35480DF90>, <Target.Target object at 0x000001C35497B950>, <Target.Target object at 0x000001C354BAB690>, <Target.Target object at 0x000001C35477D310>, <Target.Target object at 0x000001C354355610>, <Target.Target object at 0x000001C354B2CDD0>, <Target.Target object at 0x000001C354C0C150>, <Target.Target object at 0x000001C354C0C110>, <Target.Target object at 0x000001C354C0C210>, <Target.Target object at 0x000001C354C0C0D0>, <Target.Target object at 0x000001C354C0C290>, <Target.Target object at 0x000001C354C0C4D0>, <Target.Target object at 0x000001C354C0C090>, <Target.Target object at 0x000001C354C0C2D0>, <Target.Target object at 0x000001C354C0C350>, <Target.Target object at 0x000001C354C0C490>, <Target.Target object at 0x000001C354C0C450>, <Target.Target object at 0x000001C354C0C1D0>, <Target.Target object at 0x000001C354C0C310>, <Target.Target object at 0x000001C354C0C550>, <Target.Target object at 0x000001C354C0C410>, <Target.Target object at 0x000001C354C0C050>, <Target.Target object at 0x000001C354C0C7D0>, <Target.Target object at 0x000001C354C0C3D0>, <Target.Target object at 0x000001C354C0C610>, <Target.Target object at 0x000001C354C0C650>]
# target
# [[4, 1], [7, 2], [15, 2], [6, 2], [8, 2], [13, 2], [1, 7], [0, 3], [9, 3], [18, 2], [11, 6], [2, 1], [16, 3], [5, 2], [17, 2], [14, 3], [3, 2], [12, 2], [10, 3]]
# Common point:  [[4, [11, 9, 5, 18, 0, 12, 8, 2, 14]], [7, [14, 16, 5, 9, 3]], [15, [2, 18, 12, 17, 10]], [6, [3, 17, 10, 16]], [8, [18, 2, 12, 11]], [13, [16, 3, 10, 17]], [1, [17, 10, 3]], [0, [5, 14]], [9, [5, 14, 12]], [18, [12]], [11, [12]], [2, [12, 17]], [16, [3, 10]], [5, [12]], [17, [10]], [14, []], [3, []], [12, []], [10, []]]
# Số target tải mỗi cluster
# [[4, 1], [7, 2], [15, 2], [6, 2], [8, 2], [13, 2], [1, 7], [0, 3], [9, 3], [18, 4], [11, 7], [2, 3], [16, 5], [5, 8], [17, 9], [14, 5], [3, 9], [12, 8.75], [10, 6.0]]

# %%
import matplotlib.pyplot as plt
import numpy as np
# from moviepy.editor import ImageSequenceClip
from IPython.display import Video, display

plt.figure() 
image_files = []

# colors = ['red', 'blue', 'yellow', 'green', 'purple', 'pink', 'brown', 'cyan', 'magenta', 'lime', 'teal', 'lavender', 'maroon', 'olive', 'navy', 'beige', 'indigo', 'turquoise']
shapes = ['<', '>', 's', 'p', 'x', '*', '^', 'v', 'h', 's', 'p', 'o']
colors = ['aliceblue', 'antiquewhite', 'aqua', 'aquamarine', 'azure', 'beige', 'bisque', 'green', 'blanchedalmond', 'blue', 'blueviolet', 'brown', 'burlywood', 'cadetblue', 'chartreuse', 'chocolate', 'coral', 'cornflowerblue', 'cornsilk', 'crimson', 'cyan', 'darkblue', 'darkcyan', 'darkgoldenrod', 'darkgray', 'darkgreen', 'darkgrey', 'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange', 'darkorchid', 'darkred', 'darksalmon', 'darkseagreen', 'darkslateblue', 'darkslategray', 'darkslategrey', 'darkturquoise', 'darkviolet', 'deeppink', 'deepskyblue', 'dimgray', 'dimgrey', 'dodgerblue', 'firebrick', 'floralwhite', 'forestgreen', 'fuchsia', 'gainsboro', 'ghostwhite', 'gold', 'goldenrod', 'gray', 'green', 'greenyellow', 'grey', 'honeydew', 'hotpink', 'indianred', 'indigo', 'ivory', 'khaki', 'lavender', 'lavenderblush', 'lawngreen', 'lemonchiffon', 'lightblue', 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue', 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'lime', 'limegreen', 'linen', 'magenta', 'maroon', 'mediumaquamarine', 'mediumblue', 'mediumorchid', 'mediumpurple', 'mediumseagreen', 'mediumslateblue', 'mediumspringgreen', 'mediumturquoise', 'mediumvioletred', 'midnightblue', 'mintcream', 'mistyrose', 'moccasin']

# def draw(path_to_save_image):
def draw():
    plt.figure(figsize=(9, 9))
    plt.scatter(net.baseStation.location[0], net.baseStation.location[1], marker= "*", color = "purple",s = 200)
    for i in range(len(net.targets_active)):
      if net.targets_active[i] == 0:
        plt.scatter(net.listTargets[i].location[0], net.listTargets[i].location[1], color="red", marker="*",s = 200)
      else:
        plt.scatter(net.listTargets[i].location[0], net.listTargets[i].location[1], color="blue", marker="*") 
    # print(net.targets_active)

         
    
    for cluster in net.listClusters:
    #  plt.scatter(cluster.centroid[0],cluster.centroid[1],color = "black")
     for node in cluster.listNodes:
        x = node.location[0]
        y = node.location[1]
        size = 20
        color = colors[cluster.id]
        type_node = node.__class__.__name__
        if(type_node == "InNode"): marker_ = shapes[0]
        if(type_node == "OutNode"):  marker_ = shapes[1]
        if(type_node == "SensorNode"): marker_ = shapes[2]
        if(type_node == "ConnectorNode"):  marker_ = shapes[3]
        if(node.status == 0): 
          size = 30
          color = "black"

        plt.scatter(x, y, color = color , marker = marker_,s=size)
        # label = str(round(node.energy/node.capacity*100,2))  +"|"+  str(node.id)
        label = str(round(node.energy/node.capacity*100,2))
        # plt.text(x, y, label, ha='center', va='center', fontsize=6, color='black')
          
    relayNodes = [node for node in net.listNodes if node.__class__.__name__ == "RelayNode"]
    for node in relayNodes:
      color = 'orange' 
      size = 20
      x = node.location[0]
      y = node.location[1]
      if(node.status == 0): 
          size = 30
          color = "black"
      plt.scatter(x, y, color = color , marker = 'o',s=size)
      
    #   label =  str(round(node.energy/node.capacity*100,2)) +"|" +  str(node.id)
    
      label =  str(round(node.energy/node.capacity*100,2)) 
      # plt.text(x, y,label, ha='center',va = "center", fontsize=6, color='black')
    plt.show()
    # plt.savefig()


path_prefix = "result/images"     

def log(net, mcs):
    
    while True:

        if net.env.now%10 == 0:
           path = path_prefix +"/" +str(net.env.now) + ".png"
          #  draw(path) 
        print(net.env.now,net.check_nodes(),net.check_targets())
       
        yield net.env.timeout(20.0) 

# netIO = NetworkIO("physical_env/network/network_scenarios/hanoi1000n150.yaml")
# env, net = netIO.makeNetwork()

# for node in net.listNodes:
#     node.net = net
#     node.env = env
print("list clusters",len(net.listClusters))
print("list nodes",len(net.listNodes))

draw()

     
x = env.process(net.operate())
env.process(log(net, None))
env.run(until=x)

   
draw()
# Out:
# list clusters 19
# list nodes 144
# 0 0 0
# 20.0 0 1
# 40.0 0 1
# 60.0 0 1
# 80.0 0 1
# 100.0 0 1
# 120.0 0 1
# 140.0 0 1
# 160.0 0 1
# 180.0 0 1
# 200.0 0 1
# 220.0 0 1
# 240.0 0 1
# 260.0 0 1
# 280.0 0 1
# 300.0 0 1
# 320.0 0 1
# 340.0 0 1
# 360.0 0 1
# 380.0 0 1
# 400.0 0 1
# 420.0 0 1
# 440.0 0 1
# 460.0 0 1
# 480.0 0 1
# 500.0 0 1
# 520.0 0 1
# 540.0 0 1
# 560.0 0 1
# 580.0 0 1
# 600.0 0 1
# 620.0 0 1
# 640.0 0 1
# 660.0 0 1
# 680.0 0 1
# 700.0 0 1
# 720.0 0 1
# 740.0 0 1
# 760.0 0 1
# 780.0 0 1
# 800.0 0 1
# 820.0 0 1
# 840.0 0 1
# 860.0 0 1
# 880.0 0 1
# 900.0 0 1
# 920.0 0 1
# 940.0 0 1
# 960.0 0 1
# 980.0 0 1
# 1000.0 0 1
# 1020.0 0 1
# 1040.0 0 1
# 1060.0 0 1
# 1080.0 0 1
# 1100.0 0 1
# 1120.0 0 1
# 1140.0 0 1
# 1160.0 0 1
# 1180.0 0 1
# 1200.0 0 1
# 1220.0 0 1
# 1240.0 0 1
# 1260.0 0 1
# 1280.0 0 1
# 1300.0 0 1
# 1320.0 0 1
# 1340.0 0 1
# 1360.0 0 1
# 1380.0 0 1
# 1400.0 0 1
# 1420.0 0 1
# 1440.0 0 1
# 1460.0 0 1
# 1480.0 0 1
# 1500.0 0 1
# 1520.0 0 1
# 1540.0 0 1
# 1560.0 0 1
# 1580.0 0 1
# 1600.0 0 1
# 1620.0 0 1
# 1640.0 0 1
# 1660.0 0 1
# 1680.0 0 1
# 1700.0 0 1
# 1720.0 0 1
# 1740.0 0 1
# 1760.0 0 1
# 1780.0 0 1
# 1800.0 0 1
# 1820.0 0 1
# 1840.0 0 1
# 1860.0 0 1
# 1880.0 0 1
# 1900.0 0 1
# 1920.0 0 1
# 1940.0 0 1
# 1960.0 0 1
# 1980.0 0 1
# 2000.0 0 1
# 2020.0 0 1
# 2040.0 0 1
# 2060.0 0 1
# 2080.0 0 1
# 2100.0 0 1
# 2120.0 0 1
# 2140.0 0 1
# 2160.0 0 1
# 2180.0 0 1
# 2200.0 0 1
# 2220.0 0 1
# 2240.0 0 1
# 2260.0 0 1
# 2280.0 0 1
# 2300.0 0 1
# 2320.0 0 1
# 2340.0 0 1
# 2360.0 0 1
# 2380.0 0 1
# 2400.0 0 1
# 2420.0 0 1
# 2440.0 0 1
# 2460.0 0 1
# 2480.0 0 1
# 2500.0 0 1
# 2520.0 0 1
# 2540.0 0 1
# 2560.0 0 1
# 2580.0 0 1
# 2600.0 0 1
# 2620.0 0 1
# 2640.0 0 1
# 2660.0 0 1
# 2680.0 0 1
# 2700.0 0 1
# 2720.0 0 1
# 2740.0 0 1
# 2760.0 0 1
# 2780.0 0 1
# 2800.0 0 1
# 2820.0 0 1
# 2840.0 0 1
# 2860.0 0 1
# 2880.0 0 1
# 2900.0 0 1
# 2920.0 0 1
# 2940.0 0 1
# 2960.0 0 1
# 2980.0 0 1
# 3000.0 0 1
# 3020.0 0 1
# 3040.0 0 1
# 3060.0 0 1
# 3080.0 0 1
# 3100.0 0 1
# 3120.0 0 1
# 3140.0 0 1
# 3160.0 0 1
# 3180.0 0 1
# 3200.0 0 1
# 3220.0 0 1
# 3240.0 0 1
# 3260.0 0 1
# 3280.0 0 1
# 3300.0 0 1
# 3320.0 0 1
# 3340.0 0 1
# 3360.0 0 1
# 3380.0 0 1
# 3400.0 0 1
# 3420.0 0 1
# 3440.0 0 1
# 3460.0 0 1
# 3480.0 0 1
# 3500.0 0 1
# 3520.0 0 1
# 3540.0 0 1
# 3560.0 0 1
# 3580.0 0 1
# 3600.0 0 1
# 3620.0 0 1
# 3640.0 0 1
# 3660.0 0 1
# 3680.0 0 1
# 3700.0 0 1
# 3720.0 0 1
# 3740.0 0 1
# 3760.0 0 1
# 3780.0 0 1
# 3800.0 0 1
# 3820.0 0 1
# 3840.0 0 1
# 3860.0 0 1
# 3880.0 0 1
# 3900.0 0 1
# 3920.0 0 1
# 3940.0 0 1
# 3960.0 0 1
# 3980.0 0 1
# 4000.0 0 1
# 4020.0 0 1
# 4040.0 0 1
# 4060.0 0 1
# 4080.0 0 1
# 4100.0 0 1
# 4120.0 0 1
# 4140.0 0 1
# 4160.0 0 1
# 4180.0 0 1
# 4200.0 0 1
# 4220.0 0 1
# 4240.0 0 1
# 4260.0 0 1
# 4280.0 0 1
# 4300.0 0 1
# 4320.0 0 1
# 4340.0 0 1
# 4360.0 0 1
# 4380.0 0 1
# 4400.0 0 1
# 4420.0 0 1
# 4440.0 0 1
# 4460.0 0 1
# 4480.0 0 1
# 4500.0 0 1
# 4520.0 0 1
# 4540.0 0 1
# 4560.0 0 1
# 4580.0 0 1
# 4600.0 0 1
# 4620.0 0 1
# 4640.0 0 1
# 4660.0 0 1
# 4680.0 0 1
# 4700.0 0 1
# 4720.0 0 1
# 4740.0 0 1
# 4760.0 0 1
# 4780.0 0 1
# 4800.0 0 1
# 4820.0 0 1
# 4840.0 0 1
# 4860.0 0 1
# 4880.0 0 1
# 4900.0 0 1
# 4920.0 0 1
# 4940.0 0 1
# 4960.0 0 1
# 4980.0 0 1
# 5000.0 0 1
# 5020.0 0 1
# 5040.0 0 1
# 5060.0 0 1
# 5080.0 0 1
# 5100.0 0 1
# 5120.0 0 1
# 5140.0 0 1
# 5160.0 0 1
# 5180.0 0 1
# 5200.0 0 1
# 5220.0 0 1
# 5240.0 0 1
# 5260.0 0 1
# 5280.0 0 1
# 5300.0 0 1
# 5320.0 0 1
# 5340.0 0 1
# 5360.0 0 1
# 5380.0 0 1
# 5400.0 0 1
# 5420.0 0 1
# 5440.0 0 1
# 5460.0 0 1
# 5480.0 0 1
# 5500.0 0 1
# 5520.0 0 1
# 5540.0 0 1
# 5560.0 0 1
# 5580.0 0 1
# 5600.0 0 1
# 5620.0 0 1
# 5640.0 0 1
# 5660.0 0 1
# 5680.0 0 1
# 5700.0 0 1
# 5720.0 0 1
# 5740.0 0 1
# 5760.0 0 1
# 5780.0 0 1
# 5800.0 0 1
# 5820.0 0 1
# 5840.0 0 1
# 5860.0 0 1
# 5880.0 0 1
# 5900.0 0 1
# 5920.0 0 1
# 5940.0 0 1
# 5960.0 0 1
# 5980.0 0 1
# 6000.0 0 1
# 6020.0 0 1
# 6040.0 0 1
# 6060.0 0 1
# 6080.0 0 1
# 6100.0 0 1
# 6120.0 0 1
# 6140.0 0 1
# 6160.0 0 1
# 6180.0 0 1
# 6200.0 0 1
# 6220.0 0 1
# 6240.0 0 1
# 6260.0 0 1
# 6280.0 0 1
# 6300.0 0 1
# 6320.0 0 1
# 6340.0 0 1
# 6360.0 0 1
# 6380.0 0 1
# 6400.0 0 1
# 6420.0 0 1
# 6440.0 0 1
# 6460.0 0 1
# 6480.0 0 1
# 6500.0 0 1
# 6520.0 0 1
# 6540.0 0 1
# 6560.0 0 1
# 6580.0 0 1
# 6600.0 0 1
# 6620.0 0 1
# 6640.0 0 1
# 6660.0 0 1
# 6680.0 0 1
# 6700.0 0 1
# 6720.0 0 1
# 6740.0 0 1
# 6760.0 0 1
# 6780.0 0 1
# 6800.0 0 1
# 6820.0 0 1
# 6840.0 0 1
# 6860.0 0 1
# 6880.0 0 1
# 6900.0 0 1
# 6920.0 0 1
# 6940.0 0 1
# 6960.0 0 1
# 6980.0 0 1
# 7000.0 0 1
# 7020.0 0 1
# 7040.0 0 1
# 7060.0 0 1
# 7080.0 0 1
# 7100.0 0 1
# 7120.0 0 1
# 7140.0 0 1
# 7160.0 0 1
# 7180.0 0 1
# 7200.0 0 1
# 7220.0 0 1
# 7240.0 0 1
# 7260.0 0 1
# 7280.0 0 1
# 7300.0 0 1
# 7320.0 0 1
# 7340.0 0 1
# 7360.0 0 1
# 7380.0 0 1
# 7400.0 0 1
# 7420.0 0 1
# 7440.0 0 1
# 7460.0 0 1
# 7480.0 0 1
# 7500.0 0 1
# 7520.0 0 1
# 7540.0 0 1
# 7560.0 0 1
# 7580.0 0 1
# 7600.0 0 1
# 7620.0 0 1
# 7640.0 0 1
# 7660.0 0 1
# 7680.0 0 1
# 7700.0 0 1
# 7720.0 0 1
# 7740.0 0 1
# 7760.0 0 1
# 7780.0 0 1
# 7800.0 0 1
# 7820.0 0 1
# 7840.0 0 1
# 7860.0 0 1
# 7880.0 0 1
# 7900.0 0 1
# 7920.0 0 1
# 7940.0 0 1
# 7960.0 0 1
# 7980.0 0 1
# 8000.0 0 1
# 8020.0 0 1
# 8040.0 0 1
# 8060.0 0 1
# 8080.0 0 1
# 8100.0 0 1
# 8120.0 0 1
# 8140.0 0 1
# 8160.0 0 1
# 8180.0 0 1
# 8200.0 0 1
# 8220.0 0 1
# 8240.0 0 1
# 8260.0 0 1
# 8280.0 0 1
# 8300.0 0 1
# 8320.0 0 1
# 8340.0 0 1
# 8360.0 0 1
# 8380.0 0 1
# 8400.0 0 1
# 8420.0 0 1
# 8440.0 0 1
# 8460.0 0 1
# 8480.0 0 1
# 8500.0 0 1
# 8520.0 0 1
# 8540.0 0 1
# 8560.0 0 1
# 8580.0 0 1
# 8600.0 0 1
# 8620.0 0 1
# 8640.0 0 1
# 8660.0 0 1
# 8680.0 0 1
# 8700.0 0 1
# 8720.0 0 1
# 8740.0 0 1
# 8760.0 0 1
# 8780.0 0 1
# 8800.0 0 1
# 8820.0 0 1
# 8840.0 0 1
# 8860.0 0 1
# 8880.0 0 1
# 8900.0 0 1
# 8920.0 0 1
# 8940.0 0 1
# 8960.0 0 1
# 8980.0 0 1
# 9000.0 0 1
# 9020.0 0 1
# 9040.0 0 1
# 9060.0 0 1
# 9080.0 0 1
# 9100.0 0 1
# 9120.0 0 1
# 9140.0 0 1
# 9160.0 0 1
# 9180.0 0 1
# 9200.0 0 1
# 9220.0 0 1
# 9240.0 0 1
# 9260.0 0 1
# 9280.0 0 1
# 9300.0 0 1
# 9320.0 0 1
# 9340.0 0 1
# 9360.0 0 1
# 9380.0 0 1
# 9400.0 0 1
# 9420.0 0 1
# 9440.0 0 1
# 9460.0 0 1
# 9480.0 0 1
# 9500.0 0 1
# 9520.0 0 1
# 9540.0 0 1
# 9560.0 0 1
# 9580.0 0 1
# 9600.0 0 1
# 9620.0 0 1
# 9640.0 0 1
# 9660.0 0 1
# 9680.0 0 1
# 9700.0 0 1
# 9720.0 0 1
# 9740.0 0 1
# 9760.0 0 1
# 9780.0 0 1
# 9800.0 0 1
# 9820.0 0 1
# 9840.0 0 1
# 9860.0 0 1
# 9880.0 0 1
# 9900.0 0 1
# 9920.0 0 1
# 9940.0 0 1
# 9960.0 0 1
# 9980.0 0 1
# 10000.0 0 1
# 10020.0 0 1
# 10040.0 0 1
# 10060.0 0 1
# 10080.0 0 1
# 10100.0 0 1
# 10120.0 0 1
# 10140.0 0 1
# 10160.0 0 1
# 10180.0 0 1
# 10200.0 0 1
# 10220.0 0 1
# 10240.0 0 1
# 10260.0 0 1
# 10280.0 0 1
# 10300.0 0 1
# 10320.0 0 1
# 10340.0 0 1
# 10360.0 0 1
# 10380.0 0 1
# 10400.0 0 1
# 10420.0 0 1
# 10440.0 0 1
# 10460.0 0 1
# 10480.0 0 1
# 10500.0 0 1
# 10520.0 0 1
# 10540.0 0 1
# 10560.0 0 1
# 10580.0 0 1
# 10600.0 0 1
# 10620.0 0 1
# 10640.0 0 1
# 10660.0 0 1
# 10680.0 0 1
# 10700.0 0 1
# 10720.0 0 1
# 10740.0 0 1
# 10760.0 0 1
# 10780.0 0 1
# 10800.0 0 1
# 10820.0 0 1
# 10840.0 0 1
# 10860.0 0 1
# 10880.0 0 1
# 10900.0 0 1
# 10920.0 0 1
# 10940.0 0 1
# 10960.0 0 1
# 10980.0 0 1
# 11000.0 0 1
# 11020.0 0 1
# 11040.0 0 1
# 11060.0 0 1
# 11080.0 0 1
# 11100.0 0 1
# 11120.0 0 1
# 11140.0 0 1
# 11160.0 0 1
# 11180.0 0 1
# 11200.0 0 1
# 11220.0 0 1
# 11240.0 0 1
# 11260.0 0 1
# 11280.0 0 1
# 11300.0 0 1
# 11320.0 0 1
# 11340.0 0 1
# 11360.0 0 1
# 11380.0 0 1
# 11400.0 0 1
# 11420.0 0 1
# 11440.0 0 1
# 11460.0 0 1
# 11480.0 0 1
# 11500.0 0 1
# 11520.0 0 1
# 11540.0 0 1
# 11560.0 0 1
# 11580.0 0 1
# 11600.0 0 1
# 11620.0 0 1
# 11640.0 0 1
# 11660.0 0 1
# 11680.0 0 1
# 11700.0 0 1
# 11720.0 0 1
# 11740.0 0 1
# 11760.0 0 1
# 11780.0 0 1
# 11800.0 0 1
# 11820.0 0 1
# 11840.0 0 1
# 11860.0 0 1
# 11880.0 0 1
# 11900.0 0 1
# 11920.0 0 1
# 11940.0 0 1
# 11960.0 0 1
# 11980.0 0 1
# 12000.0 0 1
# 12020.0 0 1
# 12040.0 0 1
# 12060.0 0 1
# 12080.0 0 1
# 12100.0 0 1
# 12120.0 0 1
# 12140.0 0 1
# 12160.0 0 1
# 12180.0 0 1
# 12200.0 0 1
# 12220.0 0 1
# 12240.0 0 1
# 12260.0 0 1
# 12280.0 0 1
# 12300.0 0 1
# 12320.0 0 1
# 12340.0 0 1
# 12360.0 0 1
# 12380.0 0 1
# 12400.0 0 1
# 12420.0 0 1
# 12440.0 0 1
# 12460.0 0 1
# 12480.0 0 1
# 12500.0 0 1
# 12520.0 0 1
# 12540.0 0 1
# 12560.0 0 1
# 12580.0 0 1
# 12600.0 0 1
# 12620.0 0 1
# 12640.0 0 1
# 12660.0 0 1
# 12680.0 0 1
# 12700.0 0 1
# 12720.0 0 1
# 12740.0 0 1
# 12760.0 0 1
# 12780.0 0 1
# 12800.0 0 1
# 12820.0 0 1
# 12840.0 0 1
# 12860.0 0 1
# 12880.0 0 1
# 12900.0 0 1
# 12920.0 0 1
# 12940.0 0 1
# 12960.0 0 1
# 12980.0 0 1
# 13000.0 0 1
# 13020.0 0 1
# 13040.0 0 1
# 13060.0 0 1
# 13080.0 0 1
# 13100.0 0 1
# 13120.0 0 1
# 13140.0 0 1
# 13160.0 0 1
# 13180.0 0 1
# 13200.0 0 1
# 13220.0 0 1
# 13240.0 0 1
# 13260.0 0 1
# 13280.0 0 1
# 13300.0 0 1
# 13320.0 0 1
# 13340.0 0 1
# 13360.0 0 1
# 13380.0 0 1
# 13400.0 0 1
# 13420.0 0 1
# 13440.0 0 1
# 13460.0 0 1
# 13480.0 0 1
# 13500.0 0 1
# 13520.0 0 1
# 13540.0 0 1
# 13560.0 0 1
# 13580.0 0 1
# 13600.0 0 1
# 13620.0 0 1
# 13640.0 0 1
# 13660.0 0 1
# 13680.0 0 1
# 13700.0 0 1
# 13720.0 0 1
# 13740.0 0 1
# 13760.0 0 1
# 13780.0 0 1
# 13800.0 0 1
# 13820.0 0 1
# 13840.0 0 1
# 13860.0 0 1
# 13880.0 0 1
# 13900.0 0 1
# 13920.0 0 1
# 13940.0 0 1
# 13960.0 0 1
# 13980.0 0 1
# 14000.0 0 1
# 14020.0 0 1
# 14040.0 0 1
# 14060.0 0 1
# 14080.0 0 1
# 14100.0 0 1
# 14120.0 0 1
# 14140.0 0 1
# 14160.0 0 1
# 14180.0 0 1
# 14200.0 0 1
# 14220.0 0 1
# 14240.0 0 1
# 14260.0 0 1
# 14280.0 0 1
# 14300.0 0 1
# 14320.0 0 1
# 14340.0 0 1
# 14360.0 0 1
# 14380.0 0 1
# 14400.0 0 1
# 14420.0 0 1
# 14440.0 0 1
# 14460.0 0 1
# 14480.0 0 1
# 14500.0 0 1
# 14520.0 0 1
# 14540.0 0 1
# 14560.0 0 1
# 14580.0 0 1
# 14600.0 0 1
# 14620.0 0 1
# 14640.0 0 1
# 14660.0 0 1
# 14680.0 0 1
# 14700.0 0 1
# 14720.0 0 1
# 14740.0 0 1
# 14760.0 0 1
# 14780.0 0 1
# 14800.0 0 1
# 14820.0 0 1
# 14840.0 0 1
# 14860.0 0 1
# 14880.0 0 1
# 14900.0 0 1
# 14920.0 0 1
# 14940.0 0 1
# 14960.0 0 1
# 14980.0 0 1
# 15000.0 0 1
# 15020.0 0 1
# 15040.0 0 1
# 15060.0 0 1
# 15080.0 0 1
# 15100.0 0 1
# 15120.0 0 1
# 15140.0 0 1
# 15160.0 0 1
# 15180.0 0 1
# 15200.0 0 1
# 15220.0 0 1
# 15240.0 0 1
# 15260.0 0 1
# 15280.0 0 1
# 15300.0 0 1
# 15320.0 0 1
# 15340.0 0 1
# 15360.0 0 1
# 15380.0 0 1
# 15400.0 0 1
# 15420.0 0 1
# 15440.0 0 1
# 15460.0 0 1
# 15480.0 0 1
# 15500.0 0 1
# 15520.0 0 1
# 15540.0 0 1
# 15560.0 0 1
# 15580.0 0 1
# 15600.0 0 1
# 15620.0 0 1
# 15640.0 0 1
# 15660.0 0 1
# 15680.0 0 1
# 15700.0 0 1
# 15720.0 0 1
# 15740.0 0 1
# 15760.0 0 1
# 15780.0 0 1
# 15800.0 0 1
# 15820.0 0 1
# 15840.0 0 1
# 15860.0 0 1
# 15880.0 0 1
# 15900.0 0 1
# 15920.0 0 1
# 15940.0 0 1
# 15960.0 0 1
# 15980.0 0 1
# 16000.0 0 1
# 16020.0 0 1
# 16040.0 0 1
# 16060.0 0 1
# 16080.0 0 1
# 16100.0 0 1
# 16120.0 0 1
# 16140.0 0 1
# 16160.0 0 1
# 16180.0 0 1
# 16200.0 0 1
# 16220.0 0 1
# 16240.0 0 1
# 16260.0 0 1
# 16280.0 0 1
# 16300.0 0 1
# 16320.0 0 1
# 16340.0 0 1
# 16360.0 0 1
# 16380.0 0 1
# 16400.0 0 1
# 16420.0 0 1
# 16440.0 0 1
# 16460.0 0 1
# 16480.0 0 1
# 16500.0 0 1
# 16520.0 0 1
# 16540.0 0 1
# 16560.0 0 1
# 16580.0 0 1
# 16600.0 0 1
# 16620.0 0 1
# 16640.0 0 1
# 16660.0 0 1
# 16680.0 0 1
# 16700.0 0 1
# 16720.0 0 1
# 16740.0 0 1
# 16760.0 0 1
# 16780.0 0 1
# 16800.0 0 1
# 16820.0 0 1
# 16840.0 0 1
# 16860.0 0 1
# 16880.0 0 1
# 16900.0 0 1
# 16920.0 0 1
# 16940.0 0 1
# 16960.0 0 1
# 16980.0 0 1
# 17000.0 0 1
# 17020.0 0 1
# 17040.0 0 1
# 17060.0 0 1
# 17080.0 0 1
# 17100.0 0 1
# 17120.0 0 1
# 17140.0 0 1
# 17160.0 0 1
# 17180.0 0 1
# 17200.0 0 1
# 17220.0 0 1
# 17240.0 0 1
# 17260.0 0 1
# 17280.0 0 1
# 17300.0 0 1
# 17320.0 0 1
# 17340.0 0 1
# 17360.0 0 1
# 17380.0 0 1
# 17400.0 0 1
# 17420.0 0 1
# 17440.0 0 1
# 17460.0 0 1
# 17480.0 0 1
# 17500.0 0 1
# 17520.0 0 1
# 17540.0 0 1
# 17560.0 0 1
# 17580.0 0 1
# 17600.0 0 1
# 17620.0 0 1
# 17640.0 0 1
# 17660.0 0 1
# 17680.0 0 1
# 17700.0 0 1
# 17720.0 0 1
# 17740.0 0 1
# 17760.0 0 1
# 17780.0 0 1
# 17800.0 0 1
# 17820.0 0 1
# 17840.0 0 1
# 17860.0 0 1
# 17880.0 0 1
# 17900.0 0 1
# 17920.0 0 1
# 17940.0 0 1
# 17960.0 0 1
# 17980.0 0 1
# 18000.0 0 1
# 18020.0 0 1
# 18040.0 0 1
# 18060.0 0 1
# 18080.0 0 1
# 18100.0 0 1
# 18120.0 0 1
# 18140.0 0 1
# 18160.0 0 1
# 18180.0 0 1
# 18200.0 0 1
# 18220.0 0 1
# 18240.0 0 1
# 18260.0 0 1
# 18280.0 0 1
# 18300.0 0 1
# 18320.0 0 1
# 18340.0 0 1
# 18360.0 0 1
# 18380.0 0 1
# 18400.0 0 1
# 18420.0 0 1
# 18440.0 0 1
# 18460.0 0 1
# 18480.0 0 1
# 18500.0 0 1
# 18520.0 0 1
# 18540.0 0 1
# 18560.0 0 1
# 18580.0 0 1
# 18600.0 0 1
# 18620.0 0 1
# 18640.0 0 1
# 18660.0 0 1
# 18680.0 0 1
# 18700.0 0 1
# 18720.0 0 1
# 18740.0 0 1
# 18760.0 0 1
# 18780.0 0 1
# 18800.0 0 1
# 18820.0 0 1
# 18840.0 0 1
# 18860.0 0 1
# 18880.0 0 1
# 18900.0 0 1
# 18920.0 0 1
# 18940.0 0 1
# 18960.0 0 1
# 18980.0 0 1
# 19000.0 0 1
# 19020.0 0 1
# 19040.0 0 1
# 19060.0 0 1
# 19080.0 0 1
# 19100.0 0 1
# 19120.0 0 1
# 19140.0 0 1
# 19160.0 0 1
# 19180.0 0 1
# 19200.0 0 1
# 19220.0 0 1
# 19240.0 0 1
# 19260.0 0 1
# 19280.0 0 1
# 19300.0 0 1
# 19320.0 0 1
# 19340.0 0 1
# 19360.0 0 1
# 19380.0 0 1
# 19400.0 0 1
# 19420.0 0 1
# 19440.0 0 1
# 19460.0 0 1
# 19480.0 0 1
# 19500.0 0 1
# 19520.0 0 1
# 19540.0 0 1
# 19560.0 0 1
# 19580.0 0 1
# 19600.0 0 1
# 19620.0 1 1
# Network dies
# 19621.0 1 0

# %%
net.targets_active
for node in net.listNodes:
    if node.status == 0:
        print(node.__class__.__name__)

for a in net.targets_active:
    if a == 0:
        print(a)
# Out:
# OutNode
# 0
# 0
# 0
# 0
# 0
# 0

# %%
for node1 in net.listNodes:
    for node2 in net.listNodes:
        if node1.id == node2.id and node1.__class__.__name__ != node2.__class__.__name__:
            print(node1,node2)
            print(node1.id, node2.id)
            print()
# Out:
# <Nodes.OutNode.OutNode object at 0x000001C356DAE350> <Nodes.RelayNode.RelayNode object at 0x000001C356DC70D0>
# 61 61
#
# <Nodes.InNode.InNode object at 0x000001C356DAE150> <Nodes.RelayNode.RelayNode object at 0x000001C356DC6F10>
# 60 60
#
# <Nodes.InNode.InNode object at 0x000001C356DADF50> <Nodes.RelayNode.RelayNode object at 0x000001C356DC6D50>
# 59 59
#
# <Nodes.InNode.InNode object at 0x000001C356DADD50> <Nodes.RelayNode.RelayNode object at 0x000001C356DC6B90>
# 58 58
#
# <Nodes.InNode.InNode object at 0x000001C356DADB50> <Nodes.RelayNode.RelayNode object at 0x000001C356DC69D0>
# 57 57
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356DAD990> <Nodes.RelayNode.RelayNode object at 0x000001C356DC6810>
# 56 56
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356DAD7D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC6650>
# 55 55
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356DAD5D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC6490>
# 54 54
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356DAD3D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC62D0>
# 53 53
#
# <Nodes.OutNode.OutNode object at 0x000001C356DAD190> <Nodes.RelayNode.RelayNode object at 0x000001C356DC6110>
# 52 52
#
# <Nodes.OutNode.OutNode object at 0x000001C356DACFD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5F50>
# 51 51
#
# <Nodes.InNode.InNode object at 0x000001C356DACDD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5D90>
# 50 50
#
# <Nodes.SensorNode.SensorNode object at 0x000001C354766990> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5C10>
# 49 49
#
# <Nodes.OutNode.OutNode object at 0x000001C354C0D050> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5A10>
# 48 48
#
# <Nodes.InNode.InNode object at 0x000001C356D86410> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5850>
# 47 47
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356D84DD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5690>
# 46 46
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354BDD890> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5510>
# 45 45
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356D5B050> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5350>
# 44 44
#
# <Nodes.OutNode.OutNode object at 0x000001C356D59FD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC5190>
# 43 43
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356D80B10> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4FD0>
# 42 42
#
# <Nodes.OutNode.OutNode object at 0x000001C356D9E750> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4E10>
# 41 41
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356D9EC50> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4C50>
# 40 40
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356CFD3D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4A90>
# 39 39
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356CC1550> <Nodes.RelayNode.RelayNode object at 0x000001C356DC48D0>
# 38 38
#
# <Nodes.OutNode.OutNode object at 0x000001C356D6AC90> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4710>
# 37 37
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356CDDF90> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4510>
# 36 36
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356C5FC90> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4350>
# 35 35
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356CAEF50> <Nodes.RelayNode.RelayNode object at 0x000001C356DC4190>
# 34 34
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356D98710> <Nodes.RelayNode.RelayNode object at 0x000001C356DBBF90>
# 33 33
#
# <Nodes.OutNode.OutNode object at 0x000001C356D98DD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DBBE10>
# 32 32
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356D998D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DBBC50>
# 31 31
#
# <Nodes.SensorNode.SensorNode object at 0x000001C356D9B510> <Nodes.RelayNode.RelayNode object at 0x000001C356DBBA90>
# 30 30
#
# <Nodes.OutNode.OutNode object at 0x000001C356CC8450> <Nodes.RelayNode.RelayNode object at 0x000001C356DBB8D0>
# 29 29
#
# <Nodes.OutNode.OutNode object at 0x000001C354886950> <Nodes.RelayNode.RelayNode object at 0x000001C356DBB710>
# 28 28
#
# <Nodes.InNode.InNode object at 0x000001C356D44AD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DBB550>
# 27 27
#
# <Nodes.InNode.InNode object at 0x000001C356D71810> <Nodes.RelayNode.RelayNode object at 0x000001C356DBB250>
# 26 26
#
# <Nodes.OutNode.OutNode object at 0x000001C356D76310> <Nodes.RelayNode.RelayNode object at 0x000001C356DBB1D0>
# 25 25
#
# <Nodes.SensorNode.SensorNode object at 0x000001C354BF9490> <Nodes.RelayNode.RelayNode object at 0x000001C356DBB010>
# 24 24
#
# <Nodes.OutNode.OutNode object at 0x000001C354BFBE50> <Nodes.RelayNode.RelayNode object at 0x000001C356DBAE50>
# 23 23
#
# <Nodes.InNode.InNode object at 0x000001C354BF9BD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DBAC90>
# 22 22
#
# <Nodes.InNode.InNode object at 0x000001C356D02E50> <Nodes.RelayNode.RelayNode object at 0x000001C356DBAAD0>
# 21 21
#
# <Nodes.SensorNode.SensorNode object at 0x000001C3548F5D10> <Nodes.RelayNode.RelayNode object at 0x000001C356DBA910>
# 20 20
#
# <Nodes.OutNode.OutNode object at 0x000001C356C6A750> <Nodes.RelayNode.RelayNode object at 0x000001C356DBA750>
# 19 19
#
# <Nodes.InNode.InNode object at 0x000001C354C16950> <Nodes.RelayNode.RelayNode object at 0x000001C356DBA590>
# 18 18
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354C16610> <Nodes.RelayNode.RelayNode object at 0x000001C356DBA3D0>
# 17 17
#
# <Nodes.SensorNode.SensorNode object at 0x000001C354C1C690> <Nodes.RelayNode.RelayNode object at 0x000001C356DBA210>
# 16 16
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354C1C2D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DBA050>
# 15 15
#
# <Nodes.SensorNode.SensorNode object at 0x000001C354C1C150> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9E90>
# 14 14
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354BDBFD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9CD0>
# 13 13
#
# <Nodes.SensorNode.SensorNode object at 0x000001C354AF1B90> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9B10>
# 12 12
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354750B10> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9950>
# 11 11
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C3543249D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9790>
# 10 10
#
# <Nodes.SensorNode.SensorNode object at 0x000001C354327610> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9610>
# 9 9
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C3548F5DD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9450>
# 8 8
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C33329F150> <Nodes.RelayNode.RelayNode object at 0x000001C356DB9290>
# 7 7
#
# <Nodes.SensorNode.SensorNode object at 0x000001C3548F5F90> <Nodes.RelayNode.RelayNode object at 0x000001C356DB90D0>
# 6 6
#
# <Nodes.OutNode.OutNode object at 0x000001C3549859D0> <Nodes.RelayNode.RelayNode object at 0x000001C356DB8ED0>
# 5 5
#
# <Nodes.SensorNode.SensorNode object at 0x000001C354984490> <Nodes.RelayNode.RelayNode object at 0x000001C356DB8CD0>
# 4 4
#
# <Nodes.ConnectorNode.ConnectorNode object at 0x000001C3549F65D0> <Nodes.RelayNode.RelayNode object at 0x000001C356D9ED10>
# 3 3
#
# <Nodes.SensorNode.SensorNode object at 0x000001C3549F6010> <Nodes.RelayNode.RelayNode object at 0x000001C354C0EA50>
# 2 2
#
# <Nodes.OutNode.OutNode object at 0x000001C356D2BAD0> <Nodes.RelayNode.RelayNode object at 0x000001C356DB8C90>
# 1 1
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC70D0> <Nodes.OutNode.OutNode object at 0x000001C356DAE350>
# 61 61
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC6F10> <Nodes.InNode.InNode object at 0x000001C356DAE150>
# 60 60
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC6D50> <Nodes.InNode.InNode object at 0x000001C356DADF50>
# 59 59
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC6B90> <Nodes.InNode.InNode object at 0x000001C356DADD50>
# 58 58
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC69D0> <Nodes.InNode.InNode object at 0x000001C356DADB50>
# 57 57
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC6810> <Nodes.SensorNode.SensorNode object at 0x000001C356DAD990>
# 56 56
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC6650> <Nodes.SensorNode.SensorNode object at 0x000001C356DAD7D0>
# 55 55
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC6490> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356DAD5D0>
# 54 54
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC62D0> <Nodes.SensorNode.SensorNode object at 0x000001C356DAD3D0>
# 53 53
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC6110> <Nodes.OutNode.OutNode object at 0x000001C356DAD190>
# 52 52
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5F50> <Nodes.OutNode.OutNode object at 0x000001C356DACFD0>
# 51 51
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5D90> <Nodes.InNode.InNode object at 0x000001C356DACDD0>
# 50 50
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5C10> <Nodes.SensorNode.SensorNode object at 0x000001C354766990>
# 49 49
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5A10> <Nodes.OutNode.OutNode object at 0x000001C354C0D050>
# 48 48
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5850> <Nodes.InNode.InNode object at 0x000001C356D86410>
# 47 47
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5690> <Nodes.SensorNode.SensorNode object at 0x000001C356D84DD0>
# 46 46
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5510> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354BDD890>
# 45 45
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5350> <Nodes.SensorNode.SensorNode object at 0x000001C356D5B050>
# 44 44
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC5190> <Nodes.OutNode.OutNode object at 0x000001C356D59FD0>
# 43 43
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4FD0> <Nodes.SensorNode.SensorNode object at 0x000001C356D80B10>
# 42 42
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4E10> <Nodes.OutNode.OutNode object at 0x000001C356D9E750>
# 41 41
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4C50> <Nodes.SensorNode.SensorNode object at 0x000001C356D9EC50>
# 40 40
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4A90> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356CFD3D0>
# 39 39
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC48D0> <Nodes.SensorNode.SensorNode object at 0x000001C356CC1550>
# 38 38
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4710> <Nodes.OutNode.OutNode object at 0x000001C356D6AC90>
# 37 37
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4510> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356CDDF90>
# 36 36
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4350> <Nodes.SensorNode.SensorNode object at 0x000001C356C5FC90>
# 35 35
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DC4190> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C356CAEF50>
# 34 34
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBBF90> <Nodes.SensorNode.SensorNode object at 0x000001C356D98710>
# 33 33
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBBE10> <Nodes.OutNode.OutNode object at 0x000001C356D98DD0>
# 32 32
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBBC50> <Nodes.SensorNode.SensorNode object at 0x000001C356D998D0>
# 31 31
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBBA90> <Nodes.SensorNode.SensorNode object at 0x000001C356D9B510>
# 30 30
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBB8D0> <Nodes.OutNode.OutNode object at 0x000001C356CC8450>
# 29 29
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBB710> <Nodes.OutNode.OutNode object at 0x000001C354886950>
# 28 28
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBB550> <Nodes.InNode.InNode object at 0x000001C356D44AD0>
# 27 27
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBB250> <Nodes.InNode.InNode object at 0x000001C356D71810>
# 26 26
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBB1D0> <Nodes.OutNode.OutNode object at 0x000001C356D76310>
# 25 25
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBB010> <Nodes.SensorNode.SensorNode object at 0x000001C354BF9490>
# 24 24
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBAE50> <Nodes.OutNode.OutNode object at 0x000001C354BFBE50>
# 23 23
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBAC90> <Nodes.InNode.InNode object at 0x000001C354BF9BD0>
# 22 22
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBAAD0> <Nodes.InNode.InNode object at 0x000001C356D02E50>
# 21 21
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBA910> <Nodes.SensorNode.SensorNode object at 0x000001C3548F5D10>
# 20 20
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBA750> <Nodes.OutNode.OutNode object at 0x000001C356C6A750>
# 19 19
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBA590> <Nodes.InNode.InNode object at 0x000001C354C16950>
# 18 18
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBA3D0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354C16610>
# 17 17
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBA210> <Nodes.SensorNode.SensorNode object at 0x000001C354C1C690>
# 16 16
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DBA050> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354C1C2D0>
# 15 15
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9E90> <Nodes.SensorNode.SensorNode object at 0x000001C354C1C150>
# 14 14
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9CD0> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354BDBFD0>
# 13 13
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9B10> <Nodes.SensorNode.SensorNode object at 0x000001C354AF1B90>
# 12 12
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9950> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C354750B10>
# 11 11
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9790> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C3543249D0>
# 10 10
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9610> <Nodes.SensorNode.SensorNode object at 0x000001C354327610>
# 9 9
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9450> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C3548F5DD0>
# 8 8
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB9290> <Nodes.ConnectorNode.ConnectorNode object at 0x000001C33329F150>
# 7 7
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356DB90D0> <Nodes.SensorNode.SensorNode object at 0x000001C3548F5F90>
# 6 6
#
# <Nodes.RelayNode.RelayNode object at 0x000001C356D